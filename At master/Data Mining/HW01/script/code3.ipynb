# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import csv
import seaborn as sns

COLUMNS = ['AMB', 'CH4', 'CO', 'NMHC', 'NO', 'NO2',
        'NOx', 'O3', 'PM10', 'PM2.5', 'RAINFALL', 'RH',
        'SO2', 'THC', 'WD_HR', 'WIND_DIR', 'WIND_SPEED', 'WS_HR']

# %% [markdown]
# # Read in training set

# %%
def read_trainData(filename):
    # 讀入檔案
    raw_data = pd.read_csv(filename, header=None, encoding='utf8')

    # 去除標頭和多餘直行
    row, col = raw_data.shape
    raw_data  = raw_data.iloc[1:row, 3:col]              

    # 去除多餘空格
    raw_data = raw_data.replace(r'\s+', '', regex=True)  

    # 將特殊符號替換為 0
    special_chars = ['#', '*', 'x', 'A']  # 定義需要替換的特殊符號
    raw_data.replace(special_chars, 0.0, inplace=True)

    # 轉換成numpy & 浮點數型別
    data = raw_data.values 
    data = data.astype('float')

    month_to_data = {}  ## Dictionary (key:month , value:data)                                  

    # generate month_to_data(20 days data)
    for month in range(12):
        sample = np.empty(shape = (18 , 480))
        for day in range(20):
            for hour in range(24): 
                sample[:,day * 24 + hour] = data[18 * (month * 20 + day): 18 * (month * 20 + day + 1),hour]
        month_to_data[month] = sample  

    return month_to_data

# %% [markdown]
# # 分析圖

# %%
def analysis_graph(month_to_data, top_n, threshold, method='top_n'):
    data_features = np.vstack([value.T for value in month_to_data.values()])

    df_data_features = pd.DataFrame(data_features, columns=COLUMNS)
    label = np.array(df_data_features['PM2.5'][9:])
    corr_matrix = df_data_features.corr()


    print(f"================= Feature Selection - {method} =================")
 
    # 获取与 'PM2.5' 的相关性
    pm25_corr = corr_matrix['PM2.5']   
    if method == 'top_n':
        # 排序并找出与 PM2.5 最相关的前 N 个特征
        top_n =  top_n # 设置要找出的前 N 个相关特征
        top_pm25 = pm25_corr.drop('PM2.5').sort_values(ascending=False).head(top_n)
        need_features = top_pm25 
        print(f"與 PM2.5 排名最的前 {top_n} 個特徵：")
        print(top_pm25)

    elif method == 'threshold':
        # 设置一个阈值筛选出高于该值的相关性特征
        threshold = threshold  # 设定阈值 0.3
        high_corr_features = pm25_corr[pm25_corr > threshold].drop('PM2.5').sort_values(ascending=False)
        need_features = high_corr_features 
        print(f"與 PM2.5 相關性大於 {threshold} 的特徵：")
        print(high_corr_features)

    print("================= analysis graph =================")
    f,ax = plt.subplots(figsize=(9,6))
    sns.heatmap(corr_matrix, fmt='.3f', linewidths=0.5, ax=ax, cmap='coolwarm')
    plt.show()
    
    need_features = need_features.index.tolist() 
    return need_features

# %%
# input_train_path = '../input_data/train.csv'
# month_to_data = read_trainData(input_train_path)
# need_features = analysis_graph(month_to_data, top_n=17, threshold=0.2, method='threshold')

# %% [markdown]
# # Preprocess

# %%
def select_features(month_to_data, need_feature_index):
    # 遍历字典并保留每个数组中的指定行
    for key, value in month_to_data.items():
        # 保留指定的行索引
        month_to_data[key] = value[need_feature_index, :]
        
    return month_to_data

# %%
# need_feature_index = sorted([COLUMNS.index(feature) for feature in need_features]) + [9] # add PM2.5
# month_to_data = select_features(month_to_data, need_feature_index)

# print(need_features)
# print(need_feature_index)

# %%
def SetDataSets(month_to_data, feature_num, PM25_index):
    x = np.empty(shape = (12 * 471 , feature_num * 9),dtype = float)
    y = np.empty(shape = (12 * 471 , 1),dtype = float)

    for month in range(12): 
        for day in range(20): 
            for hour in range(24):   
                if day == 19 and hour > 14:
                    continue  
                x[month * 471 + day * 24 + hour,:] = month_to_data[month][:,day * 24 + hour : day * 24 + hour + 9].reshape(1,-1) 
                y[month * 471 + day * 24 + hour,0] = month_to_data[month][PM25_index ,day * 24 + hour + 9]
    return x, y

# %%
# FEATURE_NUM = len(need_feature_index)
# PM25_INDEX = FEATURE_NUM - 1
# x, y = SetDataSets(month_to_data, FEATURE_NUM, PM25_INDEX)
# print(x.shape)
# print(y.shape)
# print(x[0])
# print(y)

# %%
def Normalization(x, mean, std):
    x = x - mean
    x = x / std
    return x

# %%
# train_X, valid_X, train_Y, valid_Y = train_test_split(x, y, test_size=0.2, random_state=42)
# MEAN = np.mean(train_X, axis = 0)   #计算每个属性的均值
# STD = np.std(train_X, axis = 0)     #计算每个属性的方差

# train_X = Normalization(train_X, MEAN, STD)
# valid_X = Normalization(valid_X, MEAN, STD)

# print(train_X.shape)
# print(train_Y.shape)     
# print(valid_X.shape)
# print(valid_Y.shape)

# %% [markdown]
# # Linear Regression Agrad

# %%
def RMSE(predict_Y, real_Y):
    N = len(predict_Y)  # 樣本數量
    loss = np.sqrt(np.sum((predict_Y - real_Y)**2) / N)
    return loss

# %%
# RMSE
def traininig(train_X, train_Y, valid_X, valid_Y, epochs):
    dim = train_X.shape[1]
    w = np.zeros(shape = (dim, 1))
    learning_rate = np.array([[0.1]] * dim)
    adagrad_sum = np.zeros(shape = (dim, 1))  
    epoch = epochs
    loss_history = np.zeros([epoch, 1])         # 紀錄梯度下降損失數值，觀察收斂快慢
    loss_val_history = np.zeros([epoch, 1])     # 用来紀錄驗證集變化
    min_loss_val = 0
    print("================= traininig =================")
    for T in range(epoch):
        predict_Y = train_X.dot(w)   
        rmse_loss = RMSE(predict_Y, train_Y)
        loss_history[T] = rmse_loss
        
        
        # 紀錄驗證集變化
        pre = np.dot(valid_X, w)
        loss_val_history[T] = RMSE(pre, valid_Y)     
    
        if T % 500 == 0:
            print(f"T={T}, Training Loss: {rmse_loss:.4f}, Validation Loss: {loss_val_history[T][0]:.4f}")
        if T == 0 or min_loss_val > loss_val_history[T][0]:
            min_loss_val = loss_val_history[T][0]
            np.save(f'weight.npy',w)   ## save weight
            
        # Compute gradient (MSE gradient)
        gradient = 2 * np.dot(np.transpose(train_X), (predict_Y-train_Y)) / len(train_Y)
        
        # Update Adagrad sum
        adagrad_sum += gradient ** 2
        Sigma = np.sqrt(adagrad_sum)
        
        # Update weights using Adagrad
        w = w - learning_rate * gradient / (Sigma + 0.0006)
    
    print(f"T={epochs-1}, Training Loss: {rmse_loss:.4f}, Validation Loss: {loss_val_history[epochs-1][0]:.4f}")
    # np.save('weight.npy',w)   ## save weight
    
    return loss_history, loss_val_history

# %%
def graph_val_Train(epochs, loss_history, loss_val_history):
    epoch = np.arange(epochs)
    plt.plot(epoch, loss_history)
    plt.plot(epoch, loss_val_history) 
    plt.show()

# %%
# m, dim = train_X.shape   #获取 X_train 的行数 X_rows 和列数 X_cols
# m_val = len(valid_X)
# dim = dim + 1  #维度加 1 
# train_X = np.concatenate((np.ones([len(train_X),1]),train_X), axis = 1).astype(float)  #在X_train前面加了一列1
# valid_X = np.concatenate((np.ones([len(valid_X),1]),valid_X), axis = 1).astype(float)  #在X_val前面加了一列1
  
    
# epochs = 10000
# loss_history, loss_val_history = traininig(train_X, train_Y, valid_X, valid_Y, epochs)
# # loss_history, loss_val_history = traininig2(train_X, train_Y, valid_X, valid_Y, m_val)
# graph_val_Train(epochs, loss_history, loss_val_history)

# %% [markdown]
# # predict valid

# %%
def validation(valid_X, valid_Y):
    
    w = np.load('weight.npy')   
    valid_predict_Y = valid_X.dot(w)

    predict_rmse = RMSE(valid_predict_Y, valid_Y)
    print("================= validation =================")
    for i in range(len(valid_Y)):
        print(f"predict_Y[i], Y[i]: {valid_predict_Y[i]}, {valid_Y[i]}")
        
    print(f"predict_rmse: {predict_rmse}")
    return predict_rmse

# %%
# predict_rmse = validation(valid_X, valid_Y)
# # 4.6049422315917035 0.3 20000
# # 4.6034760721810075 0.2 20000

# %% [markdown]
# # Read in Testing set

# %%
def read_testData(filename, feautre_num, need_feature_index):
    # 讀入檔案
    raw_data = pd.read_csv(filename, header=None, encoding='utf8')

    # 去除標頭和多餘直行
    row, col = raw_data.shape
    raw_data  = raw_data.iloc[:, 2:col]              

    # 去除多餘空格
    raw_data = raw_data.replace(r'\s+', '', regex=True)  

    # 將特殊符號替換為 0
    special_chars = ['#', '*', 'x', 'A','WIND_DIR+D2070EC']  # 定義需要替換的特殊符號
    raw_data.replace(special_chars, 0.0, inplace=True)
    
    # 轉換成numpy & 浮點數型別
    data = raw_data.values 
    data = data.astype('float')

    test_row = 244
    test_x = np.empty(shape = (test_row, feautre_num * 9),dtype = float)

    for i in range(test_row):
        features_arr = data[18 * i : 18 * (i+1),:]
        clean_features = features_arr[need_feature_index, :]
        test_x[i, :] = clean_features.reshape(1, -1)


    return test_x

# %% [markdown]
# # predict test

# %%
def write_result(predict_Y):
    
    with open('../output/result.csv', "w", newline='') as f:
        w = csv.writer(f)
        title = ['index','answer']
        w.writerow(title) 
        for i in range(244):
            content = ['index_'+str(i),int(np.round(predict_Y[i][0], 0))]
            w.writerow(content) 
    
    print("write complete!")

# %%
def testing(input_test_path, feautre_num, need_feature_index, mean, std):
    test_X = read_testData(input_test_path, feautre_num, need_feature_index) 
    test_X = Normalization(test_X, mean, std)
    test_X = np.concatenate((np.ones(shape = (test_X.shape[0],1)),test_X),axis = 1).astype(float)
    
    print("================= testing =================")
    w = np.load('weight.npy') 
    predict_Y = test_X.dot(w)
    write_result(predict_Y)

# %%
# input_test_path = '../input_data/test.csv'    
# testing(input_test_path, FEATURE_NUM, MEAN, STD)

# %%
def save_diff_top_n_graph(valid_predict):
    x = np.arange(1,18)
    y = valid_predict
    plt.plot(x, y, 'ro--', linewidth=2, markersize=4)
    plt.savefig('../output/diff_top_n.png')
    plt.show()

def save_diff_test_size_graph(valid_predict, train_predict, x_1):
    x = x_1
    valid_predict.reverse()
    train_predict.reverse()
    y_1 = valid_predict
    y_2 = train_predict
    plt.plot(x, y_1, 'r*--', linewidth=1, markersize=4)
    plt.plot(x, y_2, 'b*--', linewidth=1, markersize=4)
    plt.savefig('../output/diff_training_DataSets.png')
    plt.show()
    
    for i in range(len(x)):
        print(f"DataSets: {round(x[i], 2)}, valid_predict: {valid_predict[i]}, train_predict: {train_predict[i]}")

# %% [markdown]
# # main

# %%
if __name__=='__main__':
    input_train_path = '../input_data/train.csv'
    input_test_path = '../input_data/test.csv'    
    valid_predict = []
    train_predict = []
    

    month_to_data = read_trainData(input_train_path)
    need_features = analysis_graph(month_to_data, top_n=17, threshold=0.2, method='threshold')
    
    need_feature_index = sorted([COLUMNS.index(feature) for feature in need_features]) + [9] # add PM2.5
    # need_feature_index = [0,1,2,3,4,5,6,8, 9]
    month_to_data = select_features(month_to_data, need_feature_index)
    

    FEATURE_NUM = len(need_feature_index)
    PM25_INDEX = FEATURE_NUM - 1

    x, y = SetDataSets(month_to_data, FEATURE_NUM, PM25_INDEX)    
    
    # for ratio in np.arange(0.1, 0.9, 0.01):
    ratio = 0.3
    train_X, valid_X, train_Y, valid_Y = train_test_split(x, y, test_size=ratio, random_state=42) #0.25 0.15 0.12
    MEAN = np.mean(train_X, axis = 0)   #计算每个属性的均值
    STD = np.std(train_X, axis = 0)     #计算每个属性的方差

    train_X = Normalization(train_X, MEAN, STD)
    valid_X = Normalization(valid_X, MEAN, STD)


    m, dim = train_X.shape   #获取 X_train 的行数 X_rows 和列数 X_cols
    m_val = len(valid_X)
    dim = dim + 1  #维度加 1 
    train_X = np.concatenate((np.ones([len(train_X),1]),train_X), axis = 1).astype(float)  #在train_X前面加了一列1
    valid_X = np.concatenate((np.ones([len(valid_X),1]),valid_X), axis = 1).astype(float)  #在valid_X前面加了一列1

    epochs = 60000
    loss_history, loss_val_history = traininig(train_X, train_Y, valid_X, valid_Y, epochs)
    graph_val_Train(epochs, loss_history, loss_val_history)

    predict_rmse = validation(valid_X, valid_Y)
    valid_predict.append(predict_rmse)
    
    # save_diff_test_size_graph(valid_predict, train_predict, np.arange(0.1, 0.9, 0.01))        
    testing(input_test_path, FEATURE_NUM, need_feature_index, MEAN, STD)
# Out:
# ================= Feature Selection - threshold =================
# 與 PM2.5 相關性大於 0.2 的特徵：
# PM10    0.816310
# CO      0.600925
# NMHC    0.511133
# NO2     0.499470
# NOx     0.463238
# THC     0.303378
# SO2     0.297900
# NO      0.233854
# CH4     0.218112
# Name: PM2.5, dtype: float64
# ================= analysis graph =================
# ================= traininig =================
# T=0, Training Loss: 16.8323, Validation Loss: 16.9257
# T=500, Training Loss: 10.6422, Validation Loss: 10.6243
# T=1000, Training Loss: 9.1827, Validation Loss: 9.2238
# T=1500, Training Loss: 8.1852, Validation Loss: 8.2704
# T=2000, Training Loss: 7.4305, Validation Loss: 7.5504
# T=2500, Training Loss: 6.8338, Validation Loss: 6.9821
# T=3000, Training Loss: 6.3512, Validation Loss: 6.5234
# T=3500, Training Loss: 5.9559, Validation Loss: 6.1488
# T=4000, Training Loss: 5.6301, Validation Loss: 5.8409
# T=4500, Training Loss: 5.3605, Validation Loss: 5.5870
# T=5000, Training Loss: 5.1373, Validation Loss: 5.3776
# T=5500, Training Loss: 4.9524, Validation Loss: 5.2047
# T=6000, Training Loss: 4.7995, Validation Loss: 5.0623
# T=6500, Training Loss: 4.6731, Validation Loss: 4.9450
# T=7000, Training Loss: 4.5688, Validation Loss: 4.8486
# T=7500, Training Loss: 4.4830, Validation Loss: 4.7695
# T=8000, Training Loss: 4.4124, Validation Loss: 4.7047
# T=8500, Training Loss: 4.3544, Validation Loss: 4.6516
# T=9000, Training Loss: 4.3068, Validation Loss: 4.6083
# T=9500, Training Loss: 4.2679, Validation Loss: 4.5729
# T=10000, Training Loss: 4.2360, Validation Loss: 4.5440
# T=10500, Training Loss: 4.2100, Validation Loss: 4.5205
# T=11000, Training Loss: 4.1887, Validation Loss: 4.5014
# T=11500, Training Loss: 4.1713, Validation Loss: 4.4859
# T=12000, Training Loss: 4.1571, Validation Loss: 4.4733
# T=12500, Training Loss: 4.1455, Validation Loss: 4.4630
# T=13000, Training Loss: 4.1361, Validation Loss: 4.4547
# T=13500, Training Loss: 4.1284, Validation Loss: 4.4480
# T=14000, Training Loss: 4.1221, Validation Loss: 4.4425
# T=14500, Training Loss: 4.1170, Validation Loss: 4.4381
# T=15000, Training Loss: 4.1129, Validation Loss: 4.4346
# T=15500, Training Loss: 4.1095, Validation Loss: 4.4317
# T=16000, Training Loss: 4.1067, Validation Loss: 4.4294
# T=16500, Training Loss: 4.1045, Validation Loss: 4.4275
# T=17000, Training Loss: 4.1026, Validation Loss: 4.4260
# T=17500, Training Loss: 4.1011, Validation Loss: 4.4248
# T=18000, Training Loss: 4.0999, Validation Loss: 4.4239
# T=18500, Training Loss: 4.0989, Validation Loss: 4.4231
# T=19000, Training Loss: 4.0981, Validation Loss: 4.4225
# T=19500, Training Loss: 4.0975, Validation Loss: 4.4220
# T=20000, Training Loss: 4.0969, Validation Loss: 4.4216
# T=20500, Training Loss: 4.0965, Validation Loss: 4.4213
# T=21000, Training Loss: 4.0961, Validation Loss: 4.4211
# T=21500, Training Loss: 4.0958, Validation Loss: 4.4209
# T=22000, Training Loss: 4.0956, Validation Loss: 4.4208
# T=22500, Training Loss: 4.0954, Validation Loss: 4.4207
# T=23000, Training Loss: 4.0952, Validation Loss: 4.4206
# T=23500, Training Loss: 4.0951, Validation Loss: 4.4205
# T=24000, Training Loss: 4.0950, Validation Loss: 4.4205
# T=24500, Training Loss: 4.0949, Validation Loss: 4.4205
# T=25000, Training Loss: 4.0949, Validation Loss: 4.4204
# T=25500, Training Loss: 4.0948, Validation Loss: 4.4204
# T=26000, Training Loss: 4.0947, Validation Loss: 4.4204
# T=26500, Training Loss: 4.0947, Validation Loss: 4.4204
# T=27000, Training Loss: 4.0947, Validation Loss: 4.4204
# T=27500, Training Loss: 4.0947, Validation Loss: 4.4204
# T=28000, Training Loss: 4.0946, Validation Loss: 4.4204
# T=28500, Training Loss: 4.0946, Validation Loss: 4.4204
# T=29000, Training Loss: 4.0946, Validation Loss: 4.4204
# T=29500, Training Loss: 4.0946, Validation Loss: 4.4204
# T=30000, Training Loss: 4.0946, Validation Loss: 4.4205
# T=30500, Training Loss: 4.0946, Validation Loss: 4.4205
# T=31000, Training Loss: 4.0946, Validation Loss: 4.4205
# T=31500, Training Loss: 4.0945, Validation Loss: 4.4205
# T=32000, Training Loss: 4.0945, Validation Loss: 4.4205
# T=32500, Training Loss: 4.0945, Validation Loss: 4.4205
# T=33000, Training Loss: 4.0945, Validation Loss: 4.4205
# T=33500, Training Loss: 4.0945, Validation Loss: 4.4205
# T=34000, Training Loss: 4.0945, Validation Loss: 4.4205
# T=34500, Training Loss: 4.0945, Validation Loss: 4.4205
# T=35000, Training Loss: 4.0945, Validation Loss: 4.4205
# T=35500, Training Loss: 4.0945, Validation Loss: 4.4205
# T=36000, Training Loss: 4.0945, Validation Loss: 4.4205
# T=36500, Training Loss: 4.0945, Validation Loss: 4.4205
# T=37000, Training Loss: 4.0945, Validation Loss: 4.4205
# T=37500, Training Loss: 4.0945, Validation Loss: 4.4206
# T=38000, Training Loss: 4.0945, Validation Loss: 4.4206
# T=38500, Training Loss: 4.0945, Validation Loss: 4.4206
# T=39000, Training Loss: 4.0945, Validation Loss: 4.4206
# T=39500, Training Loss: 4.0945, Validation Loss: 4.4206
# T=40000, Training Loss: 4.0945, Validation Loss: 4.4206
# T=40500, Training Loss: 4.0945, Validation Loss: 4.4206
# T=41000, Training Loss: 4.0945, Validation Loss: 4.4206
# T=41500, Training Loss: 4.0945, Validation Loss: 4.4206
# T=42000, Training Loss: 4.0945, Validation Loss: 4.4206
# T=42500, Training Loss: 4.0945, Validation Loss: 4.4206
# T=43000, Training Loss: 4.0945, Validation Loss: 4.4206
# T=43500, Training Loss: 4.0945, Validation Loss: 4.4206
# T=44000, Training Loss: 4.0945, Validation Loss: 4.4206
# T=44500, Training Loss: 4.0945, Validation Loss: 4.4206
# T=45000, Training Loss: 4.0945, Validation Loss: 4.4206
# T=45500, Training Loss: 4.0945, Validation Loss: 4.4206
# T=46000, Training Loss: 4.0945, Validation Loss: 4.4206
# T=46500, Training Loss: 4.0945, Validation Loss: 4.4206
# T=47000, Training Loss: 4.0945, Validation Loss: 4.4206
# T=47500, Training Loss: 4.0945, Validation Loss: 4.4206
# T=48000, Training Loss: 4.0945, Validation Loss: 4.4206
# T=48500, Training Loss: 4.0945, Validation Loss: 4.4206
# T=49000, Training Loss: 4.0945, Validation Loss: 4.4206
# T=49500, Training Loss: 4.0944, Validation Loss: 4.4206
# T=50000, Training Loss: 4.0944, Validation Loss: 4.4206
# T=50500, Training Loss: 4.0944, Validation Loss: 4.4206
# T=51000, Training Loss: 4.0944, Validation Loss: 4.4206
# T=51500, Training Loss: 4.0944, Validation Loss: 4.4206
# T=52000, Training Loss: 4.0944, Validation Loss: 4.4206
# T=52500, Training Loss: 4.0944, Validation Loss: 4.4206
# T=53000, Training Loss: 4.0944, Validation Loss: 4.4206
# T=53500, Training Loss: 4.0944, Validation Loss: 4.4206
# T=54000, Training Loss: 4.0944, Validation Loss: 4.4206
# T=54500, Training Loss: 4.0944, Validation Loss: 4.4206
# T=55000, Training Loss: 4.0944, Validation Loss: 4.4206
# T=55500, Training Loss: 4.0944, Validation Loss: 4.4206
# T=56000, Training Loss: 4.0944, Validation Loss: 4.4206
# T=56500, Training Loss: 4.0944, Validation Loss: 4.4206
# T=57000, Training Loss: 4.0944, Validation Loss: 4.4206
# T=57500, Training Loss: 4.0944, Validation Loss: 4.4206
# T=58000, Training Loss: 4.0944, Validation Loss: 4.4206
# T=58500, Training Loss: 4.0944, Validation Loss: 4.4206
# T=59000, Training Loss: 4.0944, Validation Loss: 4.4206
# T=59500, Training Loss: 4.0944, Validation Loss: 4.4207
# T=59999, Training Loss: 4.0944, Validation Loss: 4.4207
# ================= validation =================
# predict_Y[i], Y[i]: [9.9305478], [8.]
# predict_Y[i], Y[i]: [21.38010569], [21.]
# predict_Y[i], Y[i]: [6.546975], [4.]
# predict_Y[i], Y[i]: [9.20187459], [9.]
# predict_Y[i], Y[i]: [11.02645533], [10.]
# predict_Y[i], Y[i]: [27.93717273], [21.]
# predict_Y[i], Y[i]: [8.05034704], [10.]
# predict_Y[i], Y[i]: [8.7654885], [12.]
# predict_Y[i], Y[i]: [4.69212432], [6.]
# predict_Y[i], Y[i]: [23.9209942], [23.]
# predict_Y[i], Y[i]: [24.4401807], [28.]
# predict_Y[i], Y[i]: [4.15044976], [4.]
# predict_Y[i], Y[i]: [21.59207616], [23.]
# predict_Y[i], Y[i]: [12.60968919], [11.]
# predict_Y[i], Y[i]: [20.34787337], [15.]
# predict_Y[i], Y[i]: [16.2453321], [22.]
# predict_Y[i], Y[i]: [8.85021633], [7.]
# predict_Y[i], Y[i]: [20.74808575], [22.]
# predict_Y[i], Y[i]: [10.50084628], [8.]
# predict_Y[i], Y[i]: [21.01581994], [22.]
# predict_Y[i], Y[i]: [6.89169544], [5.]
# predict_Y[i], Y[i]: [10.48311885], [11.]
# predict_Y[i], Y[i]: [7.61928648], [7.]
# predict_Y[i], Y[i]: [6.21340766], [5.]
# predict_Y[i], Y[i]: [11.0440521], [11.]
# predict_Y[i], Y[i]: [7.79601815], [0.]
# predict_Y[i], Y[i]: [6.55909722], [5.]
# predict_Y[i], Y[i]: [11.14130441], [12.]
# predict_Y[i], Y[i]: [13.88708061], [11.]
# predict_Y[i], Y[i]: [45.69770074], [38.]
# predict_Y[i], Y[i]: [24.54450693], [27.]
# predict_Y[i], Y[i]: [0.88997233], [0.]
# predict_Y[i], Y[i]: [16.63759046], [13.]
# predict_Y[i], Y[i]: [37.53879987], [52.]
# predict_Y[i], Y[i]: [6.97601158], [10.]
# predict_Y[i], Y[i]: [10.64549079], [9.]
# predict_Y[i], Y[i]: [7.17352674], [9.]
# predict_Y[i], Y[i]: [7.78007515], [5.]
# predict_Y[i], Y[i]: [17.10226331], [10.]
# predict_Y[i], Y[i]: [1.12757634], [8.]
# predict_Y[i], Y[i]: [8.48370366], [10.]
# predict_Y[i], Y[i]: [9.67480774], [12.]
# predict_Y[i], Y[i]: [8.99906467], [8.]
# predict_Y[i], Y[i]: [8.94291837], [7.]
# predict_Y[i], Y[i]: [17.69130173], [17.]
# predict_Y[i], Y[i]: [9.28063125], [10.]
# predict_Y[i], Y[i]: [6.05922912], [3.]
# predict_Y[i], Y[i]: [17.12409381], [15.]
# predict_Y[i], Y[i]: [11.3031915], [18.]
# predict_Y[i], Y[i]: [12.05951627], [11.]
# predict_Y[i], Y[i]: [22.67370506], [17.]
# predict_Y[i], Y[i]: [17.82248847], [13.]
# predict_Y[i], Y[i]: [8.85377548], [11.]
# predict_Y[i], Y[i]: [25.01346845], [22.]
# predict_Y[i], Y[i]: [7.26032939], [3.]
# predict_Y[i], Y[i]: [10.43838885], [13.]
# predict_Y[i], Y[i]: [20.09166204], [16.]
# predict_Y[i], Y[i]: [14.4023594], [12.]
# predict_Y[i], Y[i]: [8.62496759], [11.]
# predict_Y[i], Y[i]: [11.94112105], [12.]
# predict_Y[i], Y[i]: [6.53493923], [6.]
# predict_Y[i], Y[i]: [23.87480153], [26.]
# predict_Y[i], Y[i]: [9.2449431], [0.]
# predict_Y[i], Y[i]: [10.22687592], [8.]
# predict_Y[i], Y[i]: [19.54740747], [21.]
# predict_Y[i], Y[i]: [12.83946597], [19.]
# predict_Y[i], Y[i]: [10.47595104], [7.]
# predict_Y[i], Y[i]: [10.35793668], [11.]
# predict_Y[i], Y[i]: [14.12267407], [13.]
# predict_Y[i], Y[i]: [7.04004678], [7.]
# predict_Y[i], Y[i]: [13.37060797], [14.]
# predict_Y[i], Y[i]: [59.8974259], [61.]
# predict_Y[i], Y[i]: [27.30355663], [20.]
# predict_Y[i], Y[i]: [10.65258186], [8.]
# predict_Y[i], Y[i]: [15.3078183], [13.]
# predict_Y[i], Y[i]: [8.18920159], [7.]
# predict_Y[i], Y[i]: [10.58925866], [9.]
# predict_Y[i], Y[i]: [12.08780106], [17.]
# predict_Y[i], Y[i]: [12.4932178], [8.]
# predict_Y[i], Y[i]: [13.97326316], [9.]
# predict_Y[i], Y[i]: [4.45008976], [10.]
# predict_Y[i], Y[i]: [24.4948749], [24.]
# predict_Y[i], Y[i]: [7.33019315], [9.]
# predict_Y[i], Y[i]: [25.92323434], [21.]
# predict_Y[i], Y[i]: [11.89991126], [9.]
# predict_Y[i], Y[i]: [15.23266039], [13.]
# predict_Y[i], Y[i]: [10.20618887], [2.]
# predict_Y[i], Y[i]: [12.50116519], [10.]
# predict_Y[i], Y[i]: [11.49799751], [9.]
# predict_Y[i], Y[i]: [-0.21201513], [20.]
# predict_Y[i], Y[i]: [9.64599548], [9.]
# predict_Y[i], Y[i]: [4.70808038], [7.]
# predict_Y[i], Y[i]: [19.03131833], [16.]
# predict_Y[i], Y[i]: [12.01679413], [19.]
# predict_Y[i], Y[i]: [19.25737689], [22.]
# predict_Y[i], Y[i]: [9.5005901], [11.]
# predict_Y[i], Y[i]: [19.51510316], [22.]
# predict_Y[i], Y[i]: [10.5938002], [8.]
# predict_Y[i], Y[i]: [11.77309545], [13.]
# predict_Y[i], Y[i]: [18.13934078], [10.]
# predict_Y[i], Y[i]: [33.78303509], [35.]
# predict_Y[i], Y[i]: [14.65898192], [18.]
# predict_Y[i], Y[i]: [29.65529113], [19.]
# predict_Y[i], Y[i]: [9.62920623], [12.]
# predict_Y[i], Y[i]: [7.21570221], [6.]
# predict_Y[i], Y[i]: [9.67202786], [10.]
# predict_Y[i], Y[i]: [12.29175232], [8.]
# predict_Y[i], Y[i]: [9.85853744], [7.]
# predict_Y[i], Y[i]: [11.00111696], [14.]
# predict_Y[i], Y[i]: [21.19897044], [22.]
# predict_Y[i], Y[i]: [16.11907947], [13.]
# predict_Y[i], Y[i]: [22.58137456], [17.]
# predict_Y[i], Y[i]: [12.78031435], [7.]
# predict_Y[i], Y[i]: [9.90420768], [8.]
# predict_Y[i], Y[i]: [9.91839506], [16.]
# predict_Y[i], Y[i]: [8.88921765], [6.]
# predict_Y[i], Y[i]: [10.77653477], [8.]
# predict_Y[i], Y[i]: [25.32968081], [24.]
# predict_Y[i], Y[i]: [14.82908834], [11.]
# predict_Y[i], Y[i]: [7.82551347], [4.]
# predict_Y[i], Y[i]: [15.23891037], [18.]
# predict_Y[i], Y[i]: [7.07769836], [8.]
# predict_Y[i], Y[i]: [14.53388035], [21.]
# predict_Y[i], Y[i]: [2.70280355], [4.]
# predict_Y[i], Y[i]: [13.41169425], [15.]
# predict_Y[i], Y[i]: [18.09665963], [15.]
# predict_Y[i], Y[i]: [2.94310067], [6.]
# predict_Y[i], Y[i]: [28.13372985], [29.]
# predict_Y[i], Y[i]: [8.07390331], [6.]
# predict_Y[i], Y[i]: [7.21805499], [4.]
# predict_Y[i], Y[i]: [8.29782862], [10.]
# predict_Y[i], Y[i]: [10.19363442], [6.]
# predict_Y[i], Y[i]: [33.77113274], [42.]
# predict_Y[i], Y[i]: [5.36785655], [7.]
# predict_Y[i], Y[i]: [18.98693297], [16.]
# predict_Y[i], Y[i]: [9.57357074], [10.]
# predict_Y[i], Y[i]: [11.33383984], [9.]
# predict_Y[i], Y[i]: [13.77867808], [0.]
# predict_Y[i], Y[i]: [8.10053968], [8.]
# predict_Y[i], Y[i]: [2.73444884], [3.]
# predict_Y[i], Y[i]: [11.69388565], [10.]
# predict_Y[i], Y[i]: [6.87746327], [8.]
# predict_Y[i], Y[i]: [28.25645986], [26.]
# predict_Y[i], Y[i]: [6.97284419], [17.]
# predict_Y[i], Y[i]: [16.83540569], [24.]
# predict_Y[i], Y[i]: [16.38418074], [18.]
# predict_Y[i], Y[i]: [1.43844552], [3.]
# predict_Y[i], Y[i]: [16.27466558], [11.]
# predict_Y[i], Y[i]: [8.76011779], [14.]
# predict_Y[i], Y[i]: [21.1287928], [15.]
# predict_Y[i], Y[i]: [4.59749794], [7.]
# predict_Y[i], Y[i]: [18.37602885], [25.]
# predict_Y[i], Y[i]: [8.87029822], [11.]
# predict_Y[i], Y[i]: [12.54691579], [7.]
# predict_Y[i], Y[i]: [10.07622981], [8.]
# predict_Y[i], Y[i]: [8.83438926], [11.]
# predict_Y[i], Y[i]: [11.91699773], [19.]
# predict_Y[i], Y[i]: [16.64994611], [18.]
# predict_Y[i], Y[i]: [6.79746836], [5.]
# predict_Y[i], Y[i]: [22.13240912], [26.]
# predict_Y[i], Y[i]: [9.95523977], [12.]
# predict_Y[i], Y[i]: [13.22197999], [11.]
# predict_Y[i], Y[i]: [8.28650273], [11.]
# predict_Y[i], Y[i]: [25.08828927], [32.]
# predict_Y[i], Y[i]: [11.83778714], [10.]
# predict_Y[i], Y[i]: [14.19850539], [18.]
# predict_Y[i], Y[i]: [19.19195061], [16.]
# predict_Y[i], Y[i]: [15.49658021], [11.]
# predict_Y[i], Y[i]: [7.45578615], [16.]
# predict_Y[i], Y[i]: [14.11067384], [16.]
# predict_Y[i], Y[i]: [22.3139557], [19.]
# predict_Y[i], Y[i]: [8.26883944], [5.]
# predict_Y[i], Y[i]: [77.70431858], [87.]
# predict_Y[i], Y[i]: [35.60121974], [37.]
# predict_Y[i], Y[i]: [9.5145823], [8.]
# predict_Y[i], Y[i]: [7.01268658], [5.]
# predict_Y[i], Y[i]: [10.24766175], [11.]
# predict_Y[i], Y[i]: [12.74760866], [10.]
# predict_Y[i], Y[i]: [23.17677934], [22.]
# predict_Y[i], Y[i]: [12.43246986], [10.]
# predict_Y[i], Y[i]: [13.9193791], [16.]
# predict_Y[i], Y[i]: [12.10183171], [10.]
# predict_Y[i], Y[i]: [20.18462569], [14.]
# predict_Y[i], Y[i]: [14.04970087], [17.]
# predict_Y[i], Y[i]: [5.04957413], [7.]
# predict_Y[i], Y[i]: [10.24377497], [9.]
# predict_Y[i], Y[i]: [23.55870277], [27.]
# predict_Y[i], Y[i]: [8.93458198], [11.]
# predict_Y[i], Y[i]: [5.45562111], [3.]
# predict_Y[i], Y[i]: [1.05126993], [6.]
# predict_Y[i], Y[i]: [1.97548367], [15.]
# predict_Y[i], Y[i]: [14.99665429], [12.]
# predict_Y[i], Y[i]: [11.86033767], [6.]
# predict_Y[i], Y[i]: [13.8540407], [18.]
# predict_Y[i], Y[i]: [29.39783421], [30.]
# predict_Y[i], Y[i]: [5.10767531], [3.]
# predict_Y[i], Y[i]: [10.87501492], [8.]
# predict_Y[i], Y[i]: [15.42636091], [13.]
# predict_Y[i], Y[i]: [9.05347876], [12.]
# predict_Y[i], Y[i]: [25.23994424], [31.]
# predict_Y[i], Y[i]: [9.71918991], [9.]
# predict_Y[i], Y[i]: [20.23005987], [16.]
# predict_Y[i], Y[i]: [11.13971069], [13.]
# predict_Y[i], Y[i]: [11.23453795], [2.]
# predict_Y[i], Y[i]: [34.56014085], [30.]
# predict_Y[i], Y[i]: [7.99959377], [28.]
# predict_Y[i], Y[i]: [6.72060356], [6.]
# predict_Y[i], Y[i]: [3.46365858], [4.]
# predict_Y[i], Y[i]: [10.23632405], [8.]
# predict_Y[i], Y[i]: [19.91684429], [20.]
# predict_Y[i], Y[i]: [14.20225839], [5.]
# predict_Y[i], Y[i]: [6.53223491], [7.]
# predict_Y[i], Y[i]: [15.49457576], [11.]
# predict_Y[i], Y[i]: [13.02062735], [0.]
# predict_Y[i], Y[i]: [10.39195452], [9.]
# predict_Y[i], Y[i]: [14.07829565], [20.]
# predict_Y[i], Y[i]: [26.4614082], [32.]
# predict_Y[i], Y[i]: [11.2035763], [11.]
# predict_Y[i], Y[i]: [10.23554984], [7.]
# predict_Y[i], Y[i]: [35.52641417], [42.]
# predict_Y[i], Y[i]: [9.78406882], [11.]
# predict_Y[i], Y[i]: [15.81405358], [17.]
# predict_Y[i], Y[i]: [6.59930572], [4.]
# predict_Y[i], Y[i]: [5.66787984], [14.]
# predict_Y[i], Y[i]: [11.92531598], [12.]
# predict_Y[i], Y[i]: [13.01076488], [13.]
# predict_Y[i], Y[i]: [9.02513931], [6.]
# predict_Y[i], Y[i]: [36.91328305], [34.]
# predict_Y[i], Y[i]: [7.50889548], [3.]
# predict_Y[i], Y[i]: [5.1742619], [5.]
# predict_Y[i], Y[i]: [8.05636568], [10.]
# predict_Y[i], Y[i]: [5.38105931], [0.]
# predict_Y[i], Y[i]: [32.23143745], [40.]
# predict_Y[i], Y[i]: [21.72032331], [20.]
# predict_Y[i], Y[i]: [7.69718486], [7.]
# predict_Y[i], Y[i]: [4.9409629], [4.]
# predict_Y[i], Y[i]: [6.38621051], [7.]
# predict_Y[i], Y[i]: [9.51358126], [7.]
# predict_Y[i], Y[i]: [7.59852002], [9.]
# predict_Y[i], Y[i]: [10.37682776], [11.]
# predict_Y[i], Y[i]: [8.64086383], [6.]
# predict_Y[i], Y[i]: [6.57790361], [5.]
# predict_Y[i], Y[i]: [8.59955846], [9.]
# predict_Y[i], Y[i]: [6.69095296], [11.]
# predict_Y[i], Y[i]: [11.08777667], [9.]
# predict_Y[i], Y[i]: [13.47462935], [13.]
# predict_Y[i], Y[i]: [7.72662762], [8.]
# predict_Y[i], Y[i]: [8.03856451], [0.]
# predict_Y[i], Y[i]: [8.88482965], [9.]
# predict_Y[i], Y[i]: [34.41245749], [38.]
# predict_Y[i], Y[i]: [1.96534], [0.]
# predict_Y[i], Y[i]: [13.78716598], [14.]
# predict_Y[i], Y[i]: [38.47949742], [44.]
# predict_Y[i], Y[i]: [16.44105659], [11.]
# predict_Y[i], Y[i]: [6.78187514], [0.]
# predict_Y[i], Y[i]: [6.81133268], [4.]
# predict_Y[i], Y[i]: [9.45955171], [10.]
# predict_Y[i], Y[i]: [14.17940889], [9.]
# predict_Y[i], Y[i]: [18.39991397], [18.]
# predict_Y[i], Y[i]: [10.92296333], [9.]
# predict_Y[i], Y[i]: [22.91984138], [30.]
# predict_Y[i], Y[i]: [8.57403702], [7.]
# predict_Y[i], Y[i]: [1.46894968], [0.]
# predict_Y[i], Y[i]: [7.81281937], [9.]
# predict_Y[i], Y[i]: [14.2339922], [16.]
# predict_Y[i], Y[i]: [12.81894034], [11.]
# predict_Y[i], Y[i]: [10.70775265], [12.]
# predict_Y[i], Y[i]: [28.1474008], [24.]
# predict_Y[i], Y[i]: [4.50370193], [1.]
# predict_Y[i], Y[i]: [7.76226126], [6.]
# predict_Y[i], Y[i]: [11.92446662], [17.]
# predict_Y[i], Y[i]: [19.75957238], [31.]
# predict_Y[i], Y[i]: [10.44901207], [15.]
# predict_Y[i], Y[i]: [10.97393632], [14.]
# predict_Y[i], Y[i]: [12.15831026], [12.]
# predict_Y[i], Y[i]: [22.59578576], [23.]
# predict_Y[i], Y[i]: [29.37173185], [10.]
# predict_Y[i], Y[i]: [8.39371222], [5.]
# predict_Y[i], Y[i]: [2.20338055], [0.]
# predict_Y[i], Y[i]: [16.05380227], [7.]
# predict_Y[i], Y[i]: [7.04774015], [4.]
# predict_Y[i], Y[i]: [11.71376215], [11.]
# predict_Y[i], Y[i]: [34.15572467], [33.]
# predict_Y[i], Y[i]: [4.98045488], [11.]
# predict_Y[i], Y[i]: [5.13832289], [4.]
# predict_Y[i], Y[i]: [18.92211358], [18.]
# predict_Y[i], Y[i]: [10.89753754], [11.]
# predict_Y[i], Y[i]: [18.73373363], [18.]
# predict_Y[i], Y[i]: [19.87508911], [15.]
# predict_Y[i], Y[i]: [9.12268369], [11.]
# predict_Y[i], Y[i]: [7.0848726], [6.]
# predict_Y[i], Y[i]: [11.23490329], [17.]
# predict_Y[i], Y[i]: [8.17673472], [17.]
# predict_Y[i], Y[i]: [14.2136295], [11.]
# predict_Y[i], Y[i]: [56.28508721], [34.]
# predict_Y[i], Y[i]: [16.43821342], [26.]
# predict_Y[i], Y[i]: [26.42395794], [23.]
# predict_Y[i], Y[i]: [10.65456133], [7.]
# predict_Y[i], Y[i]: [11.35079208], [10.]
# predict_Y[i], Y[i]: [9.77683094], [18.]
# predict_Y[i], Y[i]: [22.79599194], [16.]
# predict_Y[i], Y[i]: [15.70553833], [17.]
# predict_Y[i], Y[i]: [6.30677268], [5.]
# predict_Y[i], Y[i]: [10.41361662], [11.]
# predict_Y[i], Y[i]: [59.26605105], [62.]
# predict_Y[i], Y[i]: [21.02463429], [25.]
# predict_Y[i], Y[i]: [12.15660816], [8.]
# predict_Y[i], Y[i]: [24.00225175], [8.]
# predict_Y[i], Y[i]: [18.05815637], [16.]
# predict_Y[i], Y[i]: [10.71472759], [11.]
# predict_Y[i], Y[i]: [20.40531069], [21.]
# predict_Y[i], Y[i]: [16.65077776], [15.]
# predict_Y[i], Y[i]: [16.99388346], [25.]
# predict_Y[i], Y[i]: [6.87411261], [8.]
# predict_Y[i], Y[i]: [44.58263103], [33.]
# predict_Y[i], Y[i]: [35.97329943], [38.]
# predict_Y[i], Y[i]: [4.17064906], [8.]
# predict_Y[i], Y[i]: [16.75792022], [14.]
# predict_Y[i], Y[i]: [10.05073189], [12.]
# predict_Y[i], Y[i]: [16.90896827], [18.]
# predict_Y[i], Y[i]: [4.79214651], [4.]
# predict_Y[i], Y[i]: [17.67452959], [16.]
# predict_Y[i], Y[i]: [19.73520868], [19.]
# predict_Y[i], Y[i]: [21.15937723], [19.]
# predict_Y[i], Y[i]: [14.70865737], [17.]
# predict_Y[i], Y[i]: [28.43219022], [26.]
# predict_Y[i], Y[i]: [16.01605499], [12.]
# predict_Y[i], Y[i]: [15.36354087], [16.]
# predict_Y[i], Y[i]: [14.65946608], [16.]
# predict_Y[i], Y[i]: [8.43911585], [10.]
# predict_Y[i], Y[i]: [12.27996822], [13.]
# predict_Y[i], Y[i]: [8.89875103], [7.]
# predict_Y[i], Y[i]: [6.86260251], [8.]
# predict_Y[i], Y[i]: [11.15370318], [14.]
# predict_Y[i], Y[i]: [18.61752977], [21.]
# predict_Y[i], Y[i]: [8.47187394], [7.]
# predict_Y[i], Y[i]: [9.37894497], [8.]
# predict_Y[i], Y[i]: [9.40268627], [12.]
# predict_Y[i], Y[i]: [12.48465662], [16.]
# predict_Y[i], Y[i]: [34.30513821], [30.]
# predict_Y[i], Y[i]: [11.5411549], [12.]
# predict_Y[i], Y[i]: [9.71827021], [6.]
# predict_Y[i], Y[i]: [7.4749633], [6.]
# predict_Y[i], Y[i]: [15.04591327], [21.]
# predict_Y[i], Y[i]: [12.27495442], [12.]
# predict_Y[i], Y[i]: [7.47017138], [10.]
# predict_Y[i], Y[i]: [11.28378288], [11.]
# predict_Y[i], Y[i]: [15.81706525], [19.]
# predict_Y[i], Y[i]: [20.68365783], [28.]
# predict_Y[i], Y[i]: [10.48185464], [8.]
# predict_Y[i], Y[i]: [10.13158744], [9.]
# predict_Y[i], Y[i]: [27.03226134], [27.]
# predict_Y[i], Y[i]: [4.06148528], [5.]
# predict_Y[i], Y[i]: [16.71752802], [13.]
# predict_Y[i], Y[i]: [6.74517862], [5.]
# predict_Y[i], Y[i]: [12.78377071], [13.]
# predict_Y[i], Y[i]: [25.35522159], [29.]
# predict_Y[i], Y[i]: [14.38625513], [37.]
# predict_Y[i], Y[i]: [29.9523534], [41.]
# predict_Y[i], Y[i]: [30.50420489], [37.]
# predict_Y[i], Y[i]: [16.40693917], [11.]
# predict_Y[i], Y[i]: [6.34914464], [6.]
# predict_Y[i], Y[i]: [8.67453987], [17.]
# predict_Y[i], Y[i]: [4.5711085], [3.]
# predict_Y[i], Y[i]: [7.29184], [7.]
# predict_Y[i], Y[i]: [23.78990336], [27.]
# predict_Y[i], Y[i]: [9.69231566], [8.]
# predict_Y[i], Y[i]: [15.55042554], [11.]
# predict_Y[i], Y[i]: [19.25637119], [20.]
# predict_Y[i], Y[i]: [43.740862], [46.]
# predict_Y[i], Y[i]: [3.27919777], [0.]
# predict_Y[i], Y[i]: [14.27117581], [16.]
# predict_Y[i], Y[i]: [9.6801279], [9.]
# predict_Y[i], Y[i]: [3.65876976], [1.]
# predict_Y[i], Y[i]: [16.81201409], [20.]
# predict_Y[i], Y[i]: [14.09731414], [18.]
# predict_Y[i], Y[i]: [16.66967648], [17.]
# predict_Y[i], Y[i]: [13.03357498], [22.]
# predict_Y[i], Y[i]: [4.79097512], [7.]
# predict_Y[i], Y[i]: [11.13091277], [11.]
# predict_Y[i], Y[i]: [5.82186967], [5.]
# predict_Y[i], Y[i]: [16.1066088], [21.]
# predict_Y[i], Y[i]: [11.28545027], [12.]
# predict_Y[i], Y[i]: [8.21081973], [5.]
# predict_Y[i], Y[i]: [5.04782389], [5.]
# predict_Y[i], Y[i]: [5.49058919], [4.]
# predict_Y[i], Y[i]: [7.31322454], [5.]
# predict_Y[i], Y[i]: [17.80620074], [22.]
# predict_Y[i], Y[i]: [13.1970475], [14.]
# predict_Y[i], Y[i]: [10.74601896], [10.]
# predict_Y[i], Y[i]: [4.47895342], [13.]
# predict_Y[i], Y[i]: [10.48066982], [10.]
# predict_Y[i], Y[i]: [25.2035452], [22.]
# predict_Y[i], Y[i]: [5.93438728], [6.]
# predict_Y[i], Y[i]: [23.24810879], [28.]
# predict_Y[i], Y[i]: [9.98590219], [5.]
# predict_Y[i], Y[i]: [10.09373957], [10.]
# predict_Y[i], Y[i]: [21.07545331], [31.]
# predict_Y[i], Y[i]: [6.23393526], [4.]
# predict_Y[i], Y[i]: [13.86468701], [10.]
# predict_Y[i], Y[i]: [10.86551915], [11.]
# predict_Y[i], Y[i]: [8.18767522], [10.]
# predict_Y[i], Y[i]: [9.04287275], [7.]
# predict_Y[i], Y[i]: [6.55242657], [13.]
# predict_Y[i], Y[i]: [6.04818946], [4.]
# predict_Y[i], Y[i]: [-1.56691923], [13.]
# predict_Y[i], Y[i]: [8.60567319], [4.]
# predict_Y[i], Y[i]: [6.21644831], [15.]
# predict_Y[i], Y[i]: [18.17120314], [20.]
# predict_Y[i], Y[i]: [12.85435504], [13.]
# predict_Y[i], Y[i]: [24.83556877], [23.]
# predict_Y[i], Y[i]: [10.88165027], [11.]
# predict_Y[i], Y[i]: [16.09855994], [17.]
# predict_Y[i], Y[i]: [18.53879469], [20.]
# predict_Y[i], Y[i]: [8.06637832], [11.]
# predict_Y[i], Y[i]: [12.08698625], [11.]
# predict_Y[i], Y[i]: [10.8475919], [8.]
# predict_Y[i], Y[i]: [28.02155328], [21.]
# predict_Y[i], Y[i]: [29.82054291], [38.]
# predict_Y[i], Y[i]: [10.09690251], [13.]
# predict_Y[i], Y[i]: [26.34748602], [27.]
# predict_Y[i], Y[i]: [3.09840733], [3.]
# predict_Y[i], Y[i]: [5.7523802], [8.]
# predict_Y[i], Y[i]: [50.43240341], [51.]
# predict_Y[i], Y[i]: [13.47402092], [13.]
# predict_Y[i], Y[i]: [30.55064197], [27.]
# predict_Y[i], Y[i]: [3.02285682], [0.]
# predict_Y[i], Y[i]: [11.32211806], [11.]
# predict_Y[i], Y[i]: [17.61737206], [21.]
# predict_Y[i], Y[i]: [25.49555922], [30.]
# predict_Y[i], Y[i]: [10.50708109], [10.]
# predict_Y[i], Y[i]: [5.04926554], [1.]
# predict_Y[i], Y[i]: [8.46294778], [7.]
# predict_Y[i], Y[i]: [12.73098096], [13.]
# predict_Y[i], Y[i]: [19.89800222], [22.]
# predict_Y[i], Y[i]: [17.98409383], [17.]
# predict_Y[i], Y[i]: [11.43027288], [11.]
# predict_Y[i], Y[i]: [26.32466993], [22.]
# predict_Y[i], Y[i]: [16.48396905], [15.]
# predict_Y[i], Y[i]: [15.134008], [17.]
# predict_Y[i], Y[i]: [15.21946534], [11.]
# predict_Y[i], Y[i]: [12.81875141], [9.]
# predict_Y[i], Y[i]: [10.61260864], [14.]
# predict_Y[i], Y[i]: [14.97914628], [16.]
# predict_Y[i], Y[i]: [10.92882436], [10.]
# predict_Y[i], Y[i]: [32.76168297], [28.]
# predict_Y[i], Y[i]: [13.9106629], [11.]
# predict_Y[i], Y[i]: [11.614476], [12.]
# predict_Y[i], Y[i]: [13.31011837], [11.]
# predict_Y[i], Y[i]: [8.68859537], [8.]
# predict_Y[i], Y[i]: [23.25600973], [37.]
# predict_Y[i], Y[i]: [7.59308775], [6.]
# predict_Y[i], Y[i]: [23.07623033], [21.]
# predict_Y[i], Y[i]: [5.62197315], [8.]
# predict_Y[i], Y[i]: [18.93659341], [23.]
# predict_Y[i], Y[i]: [11.28430911], [9.]
# predict_Y[i], Y[i]: [15.66411293], [12.]
# predict_Y[i], Y[i]: [5.79097543], [2.]
# predict_Y[i], Y[i]: [11.86829668], [8.]
# predict_Y[i], Y[i]: [8.98782981], [6.]
# predict_Y[i], Y[i]: [12.03823581], [10.]
# predict_Y[i], Y[i]: [37.76391032], [7.]
# predict_Y[i], Y[i]: [24.38248678], [26.]
# predict_Y[i], Y[i]: [12.49898554], [17.]
# predict_Y[i], Y[i]: [24.92312679], [14.]
# predict_Y[i], Y[i]: [45.46803078], [44.]
# predict_Y[i], Y[i]: [5.65141952], [6.]
# predict_Y[i], Y[i]: [5.55126803], [8.]
# predict_Y[i], Y[i]: [5.81184106], [7.]
# predict_Y[i], Y[i]: [11.47286201], [9.]
# predict_Y[i], Y[i]: [6.50996442], [8.]
# predict_Y[i], Y[i]: [16.6599798], [25.]
# predict_Y[i], Y[i]: [8.16016737], [6.]
# predict_Y[i], Y[i]: [8.65205885], [5.]
# predict_Y[i], Y[i]: [12.89478072], [9.]
# predict_Y[i], Y[i]: [23.31775875], [37.]
# predict_Y[i], Y[i]: [7.05379283], [9.]
# predict_Y[i], Y[i]: [8.39427055], [14.]
# predict_Y[i], Y[i]: [7.54707388], [11.]
# predict_Y[i], Y[i]: [52.18093401], [63.]
# predict_Y[i], Y[i]: [11.22079373], [11.]
# predict_Y[i], Y[i]: [11.31229208], [6.]
# predict_Y[i], Y[i]: [18.03776237], [15.]
# predict_Y[i], Y[i]: [10.60677882], [11.]
# predict_Y[i], Y[i]: [10.93339826], [8.]
# predict_Y[i], Y[i]: [9.04749496], [6.]
# predict_Y[i], Y[i]: [5.2871076], [8.]
# predict_Y[i], Y[i]: [11.59417956], [7.]
# predict_Y[i], Y[i]: [8.71635446], [7.]
# predict_Y[i], Y[i]: [7.64205296], [7.]
# predict_Y[i], Y[i]: [13.15791741], [13.]
# predict_Y[i], Y[i]: [22.07058733], [20.]
# predict_Y[i], Y[i]: [13.39408996], [18.]
# predict_Y[i], Y[i]: [16.95242089], [17.]
# predict_Y[i], Y[i]: [27.85532574], [33.]
# predict_Y[i], Y[i]: [12.58364584], [9.]
# predict_Y[i], Y[i]: [9.36414821], [11.]
# predict_Y[i], Y[i]: [17.25538169], [16.]
# predict_Y[i], Y[i]: [5.27262671], [3.]
# predict_Y[i], Y[i]: [15.61603847], [13.]
# predict_Y[i], Y[i]: [11.39336927], [9.]
# predict_Y[i], Y[i]: [7.85492487], [5.]
# predict_Y[i], Y[i]: [19.39217427], [21.]
# predict_Y[i], Y[i]: [41.43089781], [35.]
# predict_Y[i], Y[i]: [11.7128779], [16.]
# predict_Y[i], Y[i]: [9.93343329], [11.]
# predict_Y[i], Y[i]: [13.02302839], [12.]
# predict_Y[i], Y[i]: [4.43124778], [7.]
# predict_Y[i], Y[i]: [11.544797], [9.]
# predict_Y[i], Y[i]: [6.21911405], [7.]
# predict_Y[i], Y[i]: [10.19860683], [22.]
# predict_Y[i], Y[i]: [12.50189177], [9.]
# predict_Y[i], Y[i]: [9.45942368], [8.]
# predict_Y[i], Y[i]: [13.7335569], [14.]
# predict_Y[i], Y[i]: [10.1623938], [13.]
# predict_Y[i], Y[i]: [12.86119014], [10.]
# predict_Y[i], Y[i]: [8.2700416], [6.]
# predict_Y[i], Y[i]: [13.65503232], [13.]
# predict_Y[i], Y[i]: [9.39063572], [13.]
# predict_Y[i], Y[i]: [4.96605834], [3.]
# predict_Y[i], Y[i]: [13.07658712], [10.]
# predict_Y[i], Y[i]: [11.01047751], [0.]
# predict_Y[i], Y[i]: [7.10738836], [5.]
# predict_Y[i], Y[i]: [6.87375354], [6.]
# predict_Y[i], Y[i]: [5.26605194], [3.]
# predict_Y[i], Y[i]: [8.38820536], [3.]
# predict_Y[i], Y[i]: [10.30988056], [11.]
# predict_Y[i], Y[i]: [15.32165053], [20.]
# predict_Y[i], Y[i]: [9.50569004], [12.]
# predict_Y[i], Y[i]: [20.25610177], [17.]
# predict_Y[i], Y[i]: [33.81839863], [42.]
# predict_Y[i], Y[i]: [12.53077265], [11.]
# predict_Y[i], Y[i]: [25.04767264], [32.]
# predict_Y[i], Y[i]: [27.95766509], [28.]
# predict_Y[i], Y[i]: [13.2661147], [17.]
# predict_Y[i], Y[i]: [18.67624962], [16.]
# predict_Y[i], Y[i]: [15.30347194], [19.]
# predict_Y[i], Y[i]: [10.90167813], [15.]
# predict_Y[i], Y[i]: [38.75415949], [43.]
# predict_Y[i], Y[i]: [18.94353128], [21.]
# predict_Y[i], Y[i]: [7.16540516], [8.]
# predict_Y[i], Y[i]: [0.69682921], [0.]
# predict_Y[i], Y[i]: [6.90150815], [7.]
# predict_Y[i], Y[i]: [3.61263434], [5.]
# predict_Y[i], Y[i]: [7.58075785], [4.]
# predict_Y[i], Y[i]: [10.21083563], [8.]
# predict_Y[i], Y[i]: [24.23878293], [19.]
# predict_Y[i], Y[i]: [13.7157837], [11.]
# predict_Y[i], Y[i]: [13.99859789], [17.]
# predict_Y[i], Y[i]: [52.39983657], [53.]
# predict_Y[i], Y[i]: [11.22700315], [11.]
# predict_Y[i], Y[i]: [4.47740034], [6.]
# predict_Y[i], Y[i]: [7.2703317], [5.]
# predict_Y[i], Y[i]: [7.28451913], [11.]
# predict_Y[i], Y[i]: [10.178314], [11.]
# predict_Y[i], Y[i]: [10.80504813], [14.]
# predict_Y[i], Y[i]: [13.23997203], [12.]
# predict_Y[i], Y[i]: [11.15970597], [15.]
# predict_Y[i], Y[i]: [9.40984241], [6.]
# predict_Y[i], Y[i]: [10.43010947], [9.]
# predict_Y[i], Y[i]: [21.70884587], [24.]
# predict_Y[i], Y[i]: [22.91297735], [23.]
# predict_Y[i], Y[i]: [23.31848556], [41.]
# predict_Y[i], Y[i]: [8.18840721], [11.]
# predict_Y[i], Y[i]: [-0.41747157], [0.]
# predict_Y[i], Y[i]: [33.81559055], [44.]
# predict_Y[i], Y[i]: [7.08946543], [1.]
# predict_Y[i], Y[i]: [6.71437602], [10.]
# predict_Y[i], Y[i]: [8.34366143], [7.]
# predict_Y[i], Y[i]: [5.22914147], [5.]
# predict_Y[i], Y[i]: [5.52938787], [8.]
# predict_Y[i], Y[i]: [7.87127845], [7.]
# predict_Y[i], Y[i]: [6.53479575], [6.]
# predict_Y[i], Y[i]: [37.65063259], [41.]
# predict_Y[i], Y[i]: [16.44402075], [18.]
# predict_Y[i], Y[i]: [31.63475956], [31.]
# predict_Y[i], Y[i]: [11.30487753], [9.]
# predict_Y[i], Y[i]: [11.72060196], [19.]
# predict_Y[i], Y[i]: [18.69739015], [23.]
# predict_Y[i], Y[i]: [18.3860374], [22.]
# predict_Y[i], Y[i]: [22.32391843], [15.]
# predict_Y[i], Y[i]: [29.29741248], [29.]
# predict_Y[i], Y[i]: [7.7262669], [8.]
# predict_Y[i], Y[i]: [6.19331101], [6.]
# predict_Y[i], Y[i]: [26.65025091], [24.]
# predict_Y[i], Y[i]: [7.83932456], [8.]
# predict_Y[i], Y[i]: [9.33535792], [13.]
# predict_Y[i], Y[i]: [14.08408698], [17.]
# predict_Y[i], Y[i]: [2.78314094], [5.]
# predict_Y[i], Y[i]: [6.18304413], [6.]
# predict_Y[i], Y[i]: [9.70841234], [9.]
# predict_Y[i], Y[i]: [7.85218013], [7.]
# predict_Y[i], Y[i]: [21.2472807], [21.]
# predict_Y[i], Y[i]: [6.3655248], [9.]
# predict_Y[i], Y[i]: [21.55762622], [21.]
# predict_Y[i], Y[i]: [15.63130599], [6.]
# predict_Y[i], Y[i]: [2.66225461], [0.]
# predict_Y[i], Y[i]: [4.5791361], [7.]
# predict_Y[i], Y[i]: [24.25973151], [19.]
# predict_Y[i], Y[i]: [10.35670126], [12.]
# predict_Y[i], Y[i]: [19.6190779], [19.]
# predict_Y[i], Y[i]: [13.3831207], [10.]
# predict_Y[i], Y[i]: [9.05095642], [16.]
# predict_Y[i], Y[i]: [10.79602002], [8.]
# predict_Y[i], Y[i]: [4.56647593], [1.]
# predict_Y[i], Y[i]: [18.78968259], [21.]
# predict_Y[i], Y[i]: [4.89275773], [7.]
# predict_Y[i], Y[i]: [4.72514323], [4.]
# predict_Y[i], Y[i]: [13.89779969], [0.]
# predict_Y[i], Y[i]: [20.47072157], [11.]
# predict_Y[i], Y[i]: [13.72534442], [11.]
# predict_Y[i], Y[i]: [15.42162023], [20.]
# predict_Y[i], Y[i]: [5.24559804], [12.]
# predict_Y[i], Y[i]: [13.39708142], [14.]
# predict_Y[i], Y[i]: [11.79840479], [7.]
# predict_Y[i], Y[i]: [3.20410844], [1.]
# predict_Y[i], Y[i]: [12.07921506], [16.]
# predict_Y[i], Y[i]: [12.05011929], [11.]
# predict_Y[i], Y[i]: [38.85850983], [46.]
# predict_Y[i], Y[i]: [9.72692051], [10.]
# predict_Y[i], Y[i]: [5.9457763], [9.]
# predict_Y[i], Y[i]: [12.97662341], [15.]
# predict_Y[i], Y[i]: [22.11298357], [20.]
# predict_Y[i], Y[i]: [23.32231161], [19.]
# predict_Y[i], Y[i]: [43.17987505], [51.]
# predict_Y[i], Y[i]: [52.06796982], [64.]
# predict_Y[i], Y[i]: [1.21576222], [0.]
# predict_Y[i], Y[i]: [3.81143833], [6.]
# predict_Y[i], Y[i]: [15.63069751], [13.]
# predict_Y[i], Y[i]: [15.7927598], [22.]
# predict_Y[i], Y[i]: [7.62458334], [4.]
# predict_Y[i], Y[i]: [15.82694526], [22.]
# predict_Y[i], Y[i]: [8.53592967], [2.]
# predict_Y[i], Y[i]: [19.31849348], [16.]
# predict_Y[i], Y[i]: [22.01833116], [22.]
# predict_Y[i], Y[i]: [5.99524312], [6.]
# predict_Y[i], Y[i]: [6.58153099], [2.]
# predict_Y[i], Y[i]: [18.65512093], [15.]
# predict_Y[i], Y[i]: [11.31012588], [10.]
# predict_Y[i], Y[i]: [32.26569817], [22.]
# predict_Y[i], Y[i]: [17.04839815], [19.]
# predict_Y[i], Y[i]: [10.95219965], [10.]
# predict_Y[i], Y[i]: [12.66426973], [11.]
# predict_Y[i], Y[i]: [7.82363156], [15.]
# predict_Y[i], Y[i]: [28.09536488], [24.]
# predict_Y[i], Y[i]: [7.00905788], [7.]
# predict_Y[i], Y[i]: [18.19941002], [14.]
# predict_Y[i], Y[i]: [8.51650928], [14.]
# predict_Y[i], Y[i]: [11.83279958], [12.]
# predict_Y[i], Y[i]: [12.14659128], [17.]
# predict_Y[i], Y[i]: [23.22454927], [21.]
# predict_Y[i], Y[i]: [4.83635443], [10.]
# predict_Y[i], Y[i]: [12.68754711], [14.]
# predict_Y[i], Y[i]: [5.26009579], [6.]
# predict_Y[i], Y[i]: [6.78571321], [7.]
# predict_Y[i], Y[i]: [9.0189517], [7.]
# predict_Y[i], Y[i]: [16.71652234], [15.]
# predict_Y[i], Y[i]: [1.4137415], [1.]
# predict_Y[i], Y[i]: [11.49287276], [11.]
# predict_Y[i], Y[i]: [60.98364438], [63.]
# predict_Y[i], Y[i]: [59.87414652], [68.]
# predict_Y[i], Y[i]: [13.76357538], [7.]
# predict_Y[i], Y[i]: [8.23053576], [8.]
# predict_Y[i], Y[i]: [14.81707946], [13.]
# predict_Y[i], Y[i]: [27.18847719], [29.]
# predict_Y[i], Y[i]: [13.03712706], [11.]
# predict_Y[i], Y[i]: [10.14194263], [7.]
# predict_Y[i], Y[i]: [11.13230697], [12.]
# predict_Y[i], Y[i]: [5.25011364], [5.]
# predict_Y[i], Y[i]: [5.67033443], [10.]
# predict_Y[i], Y[i]: [8.96706298], [7.]
# predict_Y[i], Y[i]: [27.09928475], [24.]
# predict_Y[i], Y[i]: [19.70942538], [16.]
# predict_Y[i], Y[i]: [9.6476457], [9.]
# predict_Y[i], Y[i]: [6.70690194], [4.]
# predict_Y[i], Y[i]: [7.9551471], [10.]
# predict_Y[i], Y[i]: [18.72903837], [24.]
# predict_Y[i], Y[i]: [13.818999], [16.]
# predict_Y[i], Y[i]: [5.53385997], [4.]
# predict_Y[i], Y[i]: [12.90325113], [15.]
# predict_Y[i], Y[i]: [15.24906063], [15.]
# predict_Y[i], Y[i]: [32.4765562], [50.]
# predict_Y[i], Y[i]: [20.2757327], [20.]
# predict_Y[i], Y[i]: [34.7951551], [32.]
# predict_Y[i], Y[i]: [6.39262973], [5.]
# predict_Y[i], Y[i]: [21.96499295], [32.]
# predict_Y[i], Y[i]: [9.8724252], [10.]
# predict_Y[i], Y[i]: [18.71347006], [17.]
# predict_Y[i], Y[i]: [34.19822349], [38.]
# predict_Y[i], Y[i]: [28.61598758], [33.]
# predict_Y[i], Y[i]: [14.38154743], [13.]
# predict_Y[i], Y[i]: [11.24778996], [14.]
# predict_Y[i], Y[i]: [28.58113486], [0.]
# predict_Y[i], Y[i]: [5.93647371], [10.]
# predict_Y[i], Y[i]: [16.96009857], [19.]
# predict_Y[i], Y[i]: [44.46672347], [43.]
# predict_Y[i], Y[i]: [9.84661114], [8.]
# predict_Y[i], Y[i]: [16.3306504], [15.]
# predict_Y[i], Y[i]: [7.0404802], [7.]
# predict_Y[i], Y[i]: [7.81227552], [9.]
# predict_Y[i], Y[i]: [7.55210162], [12.]
# predict_Y[i], Y[i]: [13.32020916], [19.]
# predict_Y[i], Y[i]: [17.49640984], [7.]
# predict_Y[i], Y[i]: [8.00964741], [6.]
# predict_Y[i], Y[i]: [13.44971708], [11.]
# predict_Y[i], Y[i]: [7.36173765], [6.]
# predict_Y[i], Y[i]: [11.97979228], [15.]
# predict_Y[i], Y[i]: [1.25699521], [0.]
# predict_Y[i], Y[i]: [28.05516574], [29.]
# predict_Y[i], Y[i]: [20.50217558], [27.]
# predict_Y[i], Y[i]: [14.43835552], [17.]
# predict_Y[i], Y[i]: [10.79329858], [7.]
# predict_Y[i], Y[i]: [25.44940566], [18.]
# predict_Y[i], Y[i]: [10.65287525], [14.]
# predict_Y[i], Y[i]: [10.85671108], [4.]
# predict_Y[i], Y[i]: [20.68456971], [18.]
# predict_Y[i], Y[i]: [8.62525536], [6.]
# predict_Y[i], Y[i]: [30.23250385], [44.]
# predict_Y[i], Y[i]: [12.27840194], [14.]
# predict_Y[i], Y[i]: [9.66046003], [14.]
# predict_Y[i], Y[i]: [13.23324825], [14.]
# predict_Y[i], Y[i]: [9.2694398], [9.]
# predict_Y[i], Y[i]: [7.73485248], [11.]
# predict_Y[i], Y[i]: [16.18058746], [22.]
# predict_Y[i], Y[i]: [13.59587951], [13.]
# predict_Y[i], Y[i]: [30.30112347], [27.]
# predict_Y[i], Y[i]: [7.96560608], [7.]
# predict_Y[i], Y[i]: [12.38546719], [15.]
# predict_Y[i], Y[i]: [12.95081347], [9.]
# predict_Y[i], Y[i]: [8.41300459], [13.]
# predict_Y[i], Y[i]: [8.25748766], [8.]
# predict_Y[i], Y[i]: [2.31773391], [3.]
# predict_Y[i], Y[i]: [6.64477175], [12.]
# predict_Y[i], Y[i]: [17.92783555], [20.]
# predict_Y[i], Y[i]: [14.05542404], [17.]
# predict_Y[i], Y[i]: [7.29799544], [8.]
# predict_Y[i], Y[i]: [7.52758371], [8.]
# predict_Y[i], Y[i]: [16.87714408], [17.]
# predict_Y[i], Y[i]: [10.33190329], [10.]
# predict_Y[i], Y[i]: [7.21723166], [8.]
# predict_Y[i], Y[i]: [2.89492821], [0.]
# predict_Y[i], Y[i]: [13.75354675], [12.]
# predict_Y[i], Y[i]: [15.48387975], [15.]
# predict_Y[i], Y[i]: [23.90868157], [19.]
# predict_Y[i], Y[i]: [7.34991342], [8.]
# predict_Y[i], Y[i]: [6.16436201], [5.]
# predict_Y[i], Y[i]: [12.70834653], [11.]
# predict_Y[i], Y[i]: [22.66646164], [25.]
# predict_Y[i], Y[i]: [6.82024194], [5.]
# predict_Y[i], Y[i]: [6.54220324], [15.]
# predict_Y[i], Y[i]: [12.0203706], [7.]
# predict_Y[i], Y[i]: [16.93233483], [10.]
# predict_Y[i], Y[i]: [6.10567498], [5.]
# predict_Y[i], Y[i]: [13.01845981], [10.]
# predict_Y[i], Y[i]: [1.4452945], [0.]
# predict_Y[i], Y[i]: [4.11344347], [7.]
# predict_Y[i], Y[i]: [13.96530471], [11.]
# predict_Y[i], Y[i]: [6.08372729], [5.]
# predict_Y[i], Y[i]: [6.99819708], [11.]
# predict_Y[i], Y[i]: [6.6296753], [6.]
# predict_Y[i], Y[i]: [13.74360474], [17.]
# predict_Y[i], Y[i]: [9.88498735], [9.]
# predict_Y[i], Y[i]: [13.43030997], [13.]
# predict_Y[i], Y[i]: [7.56969756], [10.]
# predict_Y[i], Y[i]: [20.82013636], [21.]
# predict_Y[i], Y[i]: [16.41936928], [16.]
# predict_Y[i], Y[i]: [18.47007519], [20.]
# predict_Y[i], Y[i]: [6.82718201], [8.]
# predict_Y[i], Y[i]: [13.44716055], [16.]
# predict_Y[i], Y[i]: [5.16442603], [8.]
# predict_Y[i], Y[i]: [15.9611999], [15.]
# predict_Y[i], Y[i]: [21.05431926], [22.]
# predict_Y[i], Y[i]: [25.99223802], [19.]
# predict_Y[i], Y[i]: [4.14582584], [7.]
# predict_Y[i], Y[i]: [11.38841795], [8.]
# predict_Y[i], Y[i]: [9.75712557], [14.]
# predict_Y[i], Y[i]: [25.53876709], [41.]
# predict_Y[i], Y[i]: [8.79263406], [14.]
# predict_Y[i], Y[i]: [10.85562805], [9.]
# predict_Y[i], Y[i]: [20.57449485], [14.]
# predict_Y[i], Y[i]: [5.03119849], [8.]
# predict_Y[i], Y[i]: [5.06171127], [10.]
# predict_Y[i], Y[i]: [16.83317585], [13.]
# predict_Y[i], Y[i]: [5.85219465], [2.]
# predict_Y[i], Y[i]: [21.00176651], [20.]
# predict_Y[i], Y[i]: [19.69959923], [14.]
# predict_Y[i], Y[i]: [9.11645764], [7.]
# predict_Y[i], Y[i]: [5.54318151], [7.]
# predict_Y[i], Y[i]: [9.76634024], [9.]
# predict_Y[i], Y[i]: [11.26279041], [12.]
# predict_Y[i], Y[i]: [9.19404454], [8.]
# predict_Y[i], Y[i]: [16.84086421], [14.]
# predict_Y[i], Y[i]: [33.79741664], [42.]
# predict_Y[i], Y[i]: [31.90895636], [31.]
# predict_Y[i], Y[i]: [7.78128268], [7.]
# predict_Y[i], Y[i]: [8.14898459], [8.]
# predict_Y[i], Y[i]: [11.76112354], [8.]
# predict_Y[i], Y[i]: [13.72585993], [11.]
# predict_Y[i], Y[i]: [7.78452638], [9.]
# predict_Y[i], Y[i]: [12.33629667], [10.]
# predict_Y[i], Y[i]: [7.27825124], [11.]
# predict_Y[i], Y[i]: [10.39465127], [7.]
# predict_Y[i], Y[i]: [5.38835316], [6.]
# predict_Y[i], Y[i]: [8.04882539], [8.]
# predict_Y[i], Y[i]: [12.22078583], [11.]
# predict_Y[i], Y[i]: [14.27765436], [14.]
# predict_Y[i], Y[i]: [14.58631208], [10.]
# predict_Y[i], Y[i]: [10.59871089], [7.]
# predict_Y[i], Y[i]: [11.94520101], [12.]
# predict_Y[i], Y[i]: [16.66885613], [14.]
# predict_Y[i], Y[i]: [11.79589057], [12.]
# predict_Y[i], Y[i]: [45.13133876], [54.]
# predict_Y[i], Y[i]: [6.29818542], [6.]
# predict_Y[i], Y[i]: [16.42350452], [14.]
# predict_Y[i], Y[i]: [16.75308547], [17.]
# predict_Y[i], Y[i]: [17.69793285], [19.]
# predict_Y[i], Y[i]: [13.48345468], [20.]
# predict_Y[i], Y[i]: [11.49269992], [15.]
# predict_Y[i], Y[i]: [7.29423745], [10.]
# predict_Y[i], Y[i]: [14.24114373], [14.]
# predict_Y[i], Y[i]: [12.37486046], [12.]
# predict_Y[i], Y[i]: [7.25342772], [9.]
# predict_Y[i], Y[i]: [8.22241588], [8.]
# predict_Y[i], Y[i]: [7.71358936], [4.]
# predict_Y[i], Y[i]: [10.03224731], [8.]
# predict_Y[i], Y[i]: [6.97159866], [3.]
# predict_Y[i], Y[i]: [10.16433977], [8.]
# predict_Y[i], Y[i]: [11.59991387], [13.]
# predict_Y[i], Y[i]: [1.91405752], [1.]
# predict_Y[i], Y[i]: [25.57190335], [30.]
# predict_Y[i], Y[i]: [6.45360942], [5.]
# predict_Y[i], Y[i]: [20.85890547], [21.]
# predict_Y[i], Y[i]: [14.23083718], [18.]
# predict_Y[i], Y[i]: [12.89966686], [14.]
# predict_Y[i], Y[i]: [32.96200968], [26.]
# predict_Y[i], Y[i]: [11.55870477], [12.]
# predict_Y[i], Y[i]: [17.89081948], [17.]
# predict_Y[i], Y[i]: [11.85333963], [11.]
# predict_Y[i], Y[i]: [4.55313697], [4.]
# predict_Y[i], Y[i]: [6.15505141], [11.]
# predict_Y[i], Y[i]: [14.38134757], [11.]
# predict_Y[i], Y[i]: [11.43064815], [16.]
# predict_Y[i], Y[i]: [15.41634259], [11.]
# predict_Y[i], Y[i]: [7.11440687], [4.]
# predict_Y[i], Y[i]: [8.48764402], [6.]
# predict_Y[i], Y[i]: [7.97324262], [9.]
# predict_Y[i], Y[i]: [8.16296422], [8.]
# predict_Y[i], Y[i]: [7.91427945], [6.]
# predict_Y[i], Y[i]: [14.28541339], [21.]
# predict_Y[i], Y[i]: [22.24004789], [22.]
# predict_Y[i], Y[i]: [8.56424492], [6.]
# predict_Y[i], Y[i]: [15.11229582], [18.]
# predict_Y[i], Y[i]: [12.20545939], [14.]
# predict_Y[i], Y[i]: [8.19556865], [8.]
# predict_Y[i], Y[i]: [6.49266218], [2.]
# predict_Y[i], Y[i]: [12.24766019], [12.]
# predict_Y[i], Y[i]: [8.27191637], [6.]
# predict_Y[i], Y[i]: [12.20101271], [11.]
# predict_Y[i], Y[i]: [18.45004926], [11.]
# predict_Y[i], Y[i]: [6.98409583], [8.]
# predict_Y[i], Y[i]: [28.39721471], [22.]
# predict_Y[i], Y[i]: [11.14873705], [11.]
# predict_Y[i], Y[i]: [11.42149935], [10.]
# predict_Y[i], Y[i]: [4.26287838], [3.]
# predict_Y[i], Y[i]: [29.25829977], [31.]
# predict_Y[i], Y[i]: [12.88183775], [8.]
# predict_Y[i], Y[i]: [12.88597267], [18.]
# predict_Y[i], Y[i]: [1.99199417], [0.]
# predict_Y[i], Y[i]: [14.02011741], [14.]
# predict_Y[i], Y[i]: [27.16897471], [35.]
# predict_Y[i], Y[i]: [10.6415525], [9.]
# predict_Y[i], Y[i]: [6.1956709], [7.]
# predict_Y[i], Y[i]: [14.13739221], [15.]
# predict_Y[i], Y[i]: [8.18276573], [7.]
# predict_Y[i], Y[i]: [9.90790777], [8.]
# predict_Y[i], Y[i]: [20.88468445], [18.]
# predict_Y[i], Y[i]: [5.99332536], [9.]
# predict_Y[i], Y[i]: [41.90543719], [0.]
# predict_Y[i], Y[i]: [8.27947111], [11.]
# predict_Y[i], Y[i]: [12.40300829], [10.]
# predict_Y[i], Y[i]: [22.3756251], [20.]
# predict_Y[i], Y[i]: [13.4367703], [15.]
# predict_Y[i], Y[i]: [10.6391055], [8.]
# predict_Y[i], Y[i]: [11.36065776], [10.]
# predict_Y[i], Y[i]: [10.75105404], [9.]
# predict_Y[i], Y[i]: [12.92770166], [11.]
# predict_Y[i], Y[i]: [16.57853454], [10.]
# predict_Y[i], Y[i]: [8.76233278], [8.]
# predict_Y[i], Y[i]: [2.91410938], [1.]
# predict_Y[i], Y[i]: [2.55735558], [4.]
# predict_Y[i], Y[i]: [7.43310991], [5.]
# predict_Y[i], Y[i]: [6.52772928], [5.]
# predict_Y[i], Y[i]: [16.05943124], [16.]
# predict_Y[i], Y[i]: [8.15320208], [7.]
# predict_Y[i], Y[i]: [13.72998304], [12.]
# predict_Y[i], Y[i]: [1.65326884], [12.]
# predict_Y[i], Y[i]: [8.98691572], [13.]
# predict_Y[i], Y[i]: [16.47731669], [13.]
# predict_Y[i], Y[i]: [9.01634272], [14.]
# predict_Y[i], Y[i]: [45.82949507], [54.]
# predict_Y[i], Y[i]: [6.37216373], [9.]
# predict_Y[i], Y[i]: [6.77321423], [9.]
# predict_Y[i], Y[i]: [3.32254808], [3.]
# predict_Y[i], Y[i]: [8.74102273], [7.]
# predict_Y[i], Y[i]: [20.10336517], [10.]
# predict_Y[i], Y[i]: [13.13479117], [17.]
# predict_Y[i], Y[i]: [15.69373363], [16.]
# predict_Y[i], Y[i]: [14.40767583], [7.]
# predict_Y[i], Y[i]: [5.66332173], [5.]
# predict_Y[i], Y[i]: [12.27360078], [12.]
# predict_Y[i], Y[i]: [9.67683241], [10.]
# predict_Y[i], Y[i]: [7.83167506], [9.]
# predict_Y[i], Y[i]: [18.32671993], [18.]
# predict_Y[i], Y[i]: [22.47065395], [26.]
# predict_Y[i], Y[i]: [6.66859958], [4.]
# predict_Y[i], Y[i]: [12.79314267], [13.]
# predict_Y[i], Y[i]: [10.49057931], [13.]
# predict_Y[i], Y[i]: [4.94899085], [6.]
# predict_Y[i], Y[i]: [40.44997138], [50.]
# predict_Y[i], Y[i]: [13.98599695], [19.]
# predict_Y[i], Y[i]: [12.49378398], [14.]
# predict_Y[i], Y[i]: [15.64069074], [9.]
# predict_Y[i], Y[i]: [11.89460731], [14.]
# predict_Y[i], Y[i]: [8.4554467], [7.]
# predict_Y[i], Y[i]: [21.84267162], [26.]
# predict_Y[i], Y[i]: [13.13932949], [11.]
# predict_Y[i], Y[i]: [20.66473089], [15.]
# predict_Y[i], Y[i]: [21.66199184], [22.]
# predict_Y[i], Y[i]: [8.45516749], [9.]
# predict_Y[i], Y[i]: [4.36126469], [6.]
# predict_Y[i], Y[i]: [17.73658412], [11.]
# predict_Y[i], Y[i]: [5.78721942], [10.]
# predict_Y[i], Y[i]: [9.04761691], [8.]
# predict_Y[i], Y[i]: [8.98319663], [5.]
# predict_Y[i], Y[i]: [14.42489119], [20.]
# predict_Y[i], Y[i]: [19.64838592], [16.]
# predict_Y[i], Y[i]: [63.65005274], [69.]
# predict_Y[i], Y[i]: [21.90140436], [26.]
# predict_Y[i], Y[i]: [19.68917852], [22.]
# predict_Y[i], Y[i]: [7.39814632], [11.]
# predict_Y[i], Y[i]: [14.32721021], [9.]
# predict_Y[i], Y[i]: [14.54649299], [12.]
# predict_Y[i], Y[i]: [12.80921511], [11.]
# predict_Y[i], Y[i]: [10.44626607], [8.]
# predict_Y[i], Y[i]: [11.27877081], [13.]
# predict_Y[i], Y[i]: [22.12315917], [26.]
# predict_Y[i], Y[i]: [16.72918887], [17.]
# predict_Y[i], Y[i]: [16.05377419], [19.]
# predict_Y[i], Y[i]: [9.84313816], [8.]
# predict_Y[i], Y[i]: [32.35695068], [27.]
# predict_Y[i], Y[i]: [6.26450513], [6.]
# predict_Y[i], Y[i]: [7.59466115], [8.]
# predict_Y[i], Y[i]: [9.18827573], [7.]
# predict_Y[i], Y[i]: [12.84949469], [10.]
# predict_Y[i], Y[i]: [17.06968235], [17.]
# predict_Y[i], Y[i]: [12.1568069], [12.]
# predict_Y[i], Y[i]: [7.7569862], [6.]
# predict_Y[i], Y[i]: [14.34336257], [19.]
# predict_Y[i], Y[i]: [2.5579115], [3.]
# predict_Y[i], Y[i]: [7.85772882], [8.]
# predict_Y[i], Y[i]: [16.83476477], [14.]
# predict_Y[i], Y[i]: [31.69378091], [39.]
# predict_Y[i], Y[i]: [2.18089008], [2.]
# predict_Y[i], Y[i]: [18.53256567], [15.]
# predict_Y[i], Y[i]: [7.28578071], [8.]
# predict_Y[i], Y[i]: [20.86142176], [16.]
# predict_Y[i], Y[i]: [12.06909007], [13.]
# predict_Y[i], Y[i]: [5.79931118], [1.]
# predict_Y[i], Y[i]: [3.15988972], [3.]
# predict_Y[i], Y[i]: [25.03353627], [24.]
# predict_Y[i], Y[i]: [9.05216654], [10.]
# predict_Y[i], Y[i]: [15.0390064], [19.]
# predict_Y[i], Y[i]: [6.44692326], [5.]
# predict_Y[i], Y[i]: [14.61571092], [12.]
# predict_Y[i], Y[i]: [6.92863911], [4.]
# predict_Y[i], Y[i]: [8.26070025], [7.]
# predict_Y[i], Y[i]: [8.2116984], [11.]
# predict_Y[i], Y[i]: [14.41283932], [16.]
# predict_Y[i], Y[i]: [18.81520374], [17.]
# predict_Y[i], Y[i]: [11.78958588], [11.]
# predict_Y[i], Y[i]: [10.38073097], [11.]
# predict_Y[i], Y[i]: [8.12797689], [12.]
# predict_Y[i], Y[i]: [21.72360469], [24.]
# predict_Y[i], Y[i]: [37.96348414], [22.]
# predict_Y[i], Y[i]: [16.07828653], [7.]
# predict_Y[i], Y[i]: [31.21591708], [32.]
# predict_Y[i], Y[i]: [17.00584032], [9.]
# predict_Y[i], Y[i]: [13.22156269], [17.]
# predict_Y[i], Y[i]: [11.45808186], [11.]
# predict_Y[i], Y[i]: [13.5858094], [13.]
# predict_Y[i], Y[i]: [3.1553246], [7.]
# predict_Y[i], Y[i]: [10.71262886], [8.]
# predict_Y[i], Y[i]: [14.33637424], [15.]
# predict_Y[i], Y[i]: [4.48464043], [1.]
# predict_Y[i], Y[i]: [8.72644577], [8.]
# predict_Y[i], Y[i]: [7.71739437], [12.]
# predict_Y[i], Y[i]: [22.64837506], [24.]
# predict_Y[i], Y[i]: [6.08617085], [4.]
# predict_Y[i], Y[i]: [14.50995178], [23.]
# predict_Y[i], Y[i]: [6.14766017], [8.]
# predict_Y[i], Y[i]: [8.08081154], [6.]
# predict_Y[i], Y[i]: [13.45482247], [13.]
# predict_Y[i], Y[i]: [8.48666226], [9.]
# predict_Y[i], Y[i]: [4.46207326], [5.]
# predict_Y[i], Y[i]: [12.59220168], [16.]
# predict_Y[i], Y[i]: [28.10015105], [34.]
# predict_Y[i], Y[i]: [5.42234979], [5.]
# predict_Y[i], Y[i]: [21.46872545], [15.]
# predict_Y[i], Y[i]: [5.02330707], [5.]
# predict_Y[i], Y[i]: [27.33812764], [15.]
# predict_Y[i], Y[i]: [6.48732875], [11.]
# predict_Y[i], Y[i]: [8.53814522], [9.]
# predict_Y[i], Y[i]: [10.10334168], [10.]
# predict_Y[i], Y[i]: [11.73796136], [11.]
# predict_Y[i], Y[i]: [9.53691707], [7.]
# predict_Y[i], Y[i]: [10.87334934], [10.]
# predict_Y[i], Y[i]: [16.68857202], [25.]
# ...
# predict_Y[i], Y[i]: [9.94990174], [11.]
# predict_Y[i], Y[i]: [12.7265769], [9.]
# predict_Y[i], Y[i]: [6.33096419], [4.]
# predict_Y[i], Y[i]: [12.40291551], [11.]
# predict_Y[i], Y[i]: [11.73372731], [9.]
# predict_Y[i], Y[i]: [6.03106479], [3.]
# predict_Y[i], Y[i]: [15.19459643], [11.]
# predict_Y[i], Y[i]: [25.69388411], [30.]
# predict_Y[i], Y[i]: [12.75233269], [8.]
# predict_Y[i], Y[i]: [11.34872562], [11.]
# predict_Y[i], Y[i]: [26.01733125], [24.]
# predict_Y[i], Y[i]: [44.49050288], [53.]
# predict_Y[i], Y[i]: [6.72652778], [6.]
# predict_Y[i], Y[i]: [10.0338564], [11.]
# predict_Y[i], Y[i]: [7.66791034], [6.]
# predict_Y[i], Y[i]: [14.2772752], [11.]
# predict_Y[i], Y[i]: [0.74793961], [0.]
# predict_Y[i], Y[i]: [3.20194643], [16.]
# predict_Y[i], Y[i]: [9.94859463], [7.]
# predict_Y[i], Y[i]: [18.72642579], [14.]
# predict_Y[i], Y[i]: [18.0307426], [9.]
# predict_Y[i], Y[i]: [5.46212889], [4.]
# predict_Y[i], Y[i]: [9.36331807], [9.]
# predict_Y[i], Y[i]: [8.03467586], [7.]
# predict_Y[i], Y[i]: [11.98632134], [11.]
# predict_Y[i], Y[i]: [-2.58300558], [15.]
# predict_Y[i], Y[i]: [10.33464298], [15.]
# predict_Y[i], Y[i]: [4.33137346], [2.]
# predict_Y[i], Y[i]: [19.46563593], [16.]
# predict_Y[i], Y[i]: [4.85957343], [6.]
# predict_Y[i], Y[i]: [8.18690256], [9.]
# predict_Y[i], Y[i]: [8.39418373], [11.]
# predict_Y[i], Y[i]: [7.34355496], [4.]
# predict_Y[i], Y[i]: [5.23571729], [4.]
# predict_Y[i], Y[i]: [4.3284915], [1.]
# predict_Y[i], Y[i]: [9.37030074], [5.]
# predict_Y[i], Y[i]: [7.807661], [11.]
# predict_Y[i], Y[i]: [4.97996577], [3.]
# predict_Y[i], Y[i]: [8.34260184], [9.]
# predict_Y[i], Y[i]: [29.7077692], [27.]
# predict_Y[i], Y[i]: [8.52419544], [9.]
# predict_Y[i], Y[i]: [4.64062252], [11.]
# predict_Y[i], Y[i]: [17.58329793], [14.]
# predict_Y[i], Y[i]: [25.2201758], [22.]
# predict_Y[i], Y[i]: [4.70082049], [4.]
# predict_Y[i], Y[i]: [18.27053833], [23.]
# predict_Y[i], Y[i]: [34.21318823], [22.]
# predict_Y[i], Y[i]: [5.8314216], [0.]
# predict_Y[i], Y[i]: [7.68643571], [8.]
# predict_Y[i], Y[i]: [39.20143006], [43.]
# predict_Y[i], Y[i]: [6.06470846], [15.]
# predict_Y[i], Y[i]: [8.0082851], [7.]
# predict_Y[i], Y[i]: [27.39232798], [30.]
# predict_Y[i], Y[i]: [27.51509704], [25.]
# predict_Y[i], Y[i]: [12.40241222], [13.]
# predict_Y[i], Y[i]: [7.66023585], [5.]
# predict_Y[i], Y[i]: [31.46778526], [29.]
# predict_Y[i], Y[i]: [9.70630774], [10.]
# predict_Y[i], Y[i]: [8.14055079], [7.]
# predict_Y[i], Y[i]: [7.27984281], [7.]
# predict_Y[i], Y[i]: [7.68597718], [5.]
# predict_Y[i], Y[i]: [5.71911742], [16.]
# predict_Y[i], Y[i]: [8.50475076], [7.]
# predict_Y[i], Y[i]: [9.94054797], [9.]
# predict_Y[i], Y[i]: [6.54867956], [7.]
# predict_Y[i], Y[i]: [18.7863956], [22.]
# predict_Y[i], Y[i]: [56.34974219], [65.]
# predict_Y[i], Y[i]: [10.3970563], [8.]
# predict_Y[i], Y[i]: [17.45677036], [15.]
# predict_Y[i], Y[i]: [4.39420234], [15.]
# predict_Y[i], Y[i]: [6.36388633], [11.]
# predict_Y[i], Y[i]: [9.37686806], [9.]
# predict_Y[i], Y[i]: [24.56405612], [20.]
# predict_Y[i], Y[i]: [13.25264757], [18.]
# predict_Y[i], Y[i]: [9.82328642], [9.]
# predict_Y[i], Y[i]: [36.72407818], [36.]
# predict_Y[i], Y[i]: [12.20251072], [9.]
# predict_Y[i], Y[i]: [37.7720561], [40.]
# predict_Y[i], Y[i]: [11.44636976], [13.]
# predict_Y[i], Y[i]: [6.80145356], [10.]
# predict_Y[i], Y[i]: [15.65618953], [19.]
# predict_Y[i], Y[i]: [21.54650425], [13.]
# predict_Y[i], Y[i]: [5.56648005], [5.]
# predict_Y[i], Y[i]: [14.78800074], [18.]
# predict_Y[i], Y[i]: [26.68121227], [26.]
# predict_Y[i], Y[i]: [8.55457226], [10.]
# predict_Y[i], Y[i]: [11.27912773], [15.]
# predict_Y[i], Y[i]: [19.97433829], [18.]
# predict_Y[i], Y[i]: [11.14282059], [10.]
# predict_Y[i], Y[i]: [12.32860818], [14.]
# predict_Y[i], Y[i]: [21.48379852], [23.]
# predict_Y[i], Y[i]: [6.87812254], [4.]
# predict_Y[i], Y[i]: [8.26598586], [11.]
# predict_Y[i], Y[i]: [16.5241768], [13.]
# predict_Y[i], Y[i]: [10.92257328], [8.]
# predict_Y[i], Y[i]: [14.13121156], [14.]
# predict_Y[i], Y[i]: [12.98956423], [14.]
# predict_Y[i], Y[i]: [13.97249108], [7.]
# predict_Y[i], Y[i]: [5.49071121], [5.]
# predict_Y[i], Y[i]: [16.1708019], [22.]
# predict_Y[i], Y[i]: [7.65925724], [5.]
# predict_Y[i], Y[i]: [11.27112373], [15.]
# predict_Y[i], Y[i]: [8.44900448], [11.]
# predict_Y[i], Y[i]: [5.32001038], [6.]
# predict_Y[i], Y[i]: [18.65547553], [20.]
# predict_Y[i], Y[i]: [6.8797201], [10.]
# predict_Y[i], Y[i]: [10.91769443], [23.]
# predict_Y[i], Y[i]: [10.50374186], [9.]
# predict_Y[i], Y[i]: [8.26005276], [7.]
# predict_Y[i], Y[i]: [16.11150901], [20.]
# predict_Y[i], Y[i]: [18.39429813], [16.]
# predict_Y[i], Y[i]: [11.6775402], [11.]
# predict_Y[i], Y[i]: [33.03889925], [25.]
# predict_Y[i], Y[i]: [16.20684332], [19.]
# predict_Y[i], Y[i]: [4.70687071], [3.]
# predict_Y[i], Y[i]: [8.06703767], [6.]
# predict_Y[i], Y[i]: [9.90130656], [12.]
# predict_Y[i], Y[i]: [30.20216446], [32.]
# predict_Y[i], Y[i]: [9.79197467], [12.]
# predict_Y[i], Y[i]: [35.01124749], [33.]
# predict_Y[i], Y[i]: [16.88512239], [13.]
# predict_Y[i], Y[i]: [31.36886426], [30.]
# predict_Y[i], Y[i]: [12.03336522], [15.]
# predict_Y[i], Y[i]: [7.96039244], [7.]
# predict_Y[i], Y[i]: [27.02134145], [36.]
# predict_Y[i], Y[i]: [9.24520824], [9.]
# predict_Y[i], Y[i]: [9.31738312], [7.]
# predict_Y[i], Y[i]: [18.19640633], [20.]
# predict_Y[i], Y[i]: [6.80925213], [9.]
# predict_Y[i], Y[i]: [11.57784879], [10.]
# predict_Y[i], Y[i]: [4.15855314], [3.]
# predict_Y[i], Y[i]: [21.08495068], [26.]
# predict_Y[i], Y[i]: [17.61562971], [15.]
# predict_Y[i], Y[i]: [32.81428127], [39.]
# predict_Y[i], Y[i]: [15.66974246], [18.]
# predict_Y[i], Y[i]: [10.96415283], [10.]
# predict_Y[i], Y[i]: [15.59228876], [15.]
# predict_Y[i], Y[i]: [21.55369713], [17.]
# predict_Y[i], Y[i]: [7.40968893], [12.]
# predict_Y[i], Y[i]: [14.61441931], [12.]
# predict_Y[i], Y[i]: [8.53543304], [12.]
# predict_Y[i], Y[i]: [14.50523728], [7.]
# predict_Y[i], Y[i]: [13.95601785], [12.]
# predict_Y[i], Y[i]: [6.72086641], [1.]
# predict_Y[i], Y[i]: [17.64969529], [17.]
# predict_Y[i], Y[i]: [14.36123831], [16.]
# predict_Y[i], Y[i]: [9.40894314], [10.]
# predict_Y[i], Y[i]: [9.73023004], [10.]
# predict_Y[i], Y[i]: [7.29228841], [9.]
# predict_Y[i], Y[i]: [8.47780995], [13.]
# predict_Y[i], Y[i]: [6.9963056], [11.]
# predict_Y[i], Y[i]: [10.89342608], [9.]
# predict_Y[i], Y[i]: [1.49750897], [0.]
# predict_Y[i], Y[i]: [9.49992315], [8.]
# predict_Y[i], Y[i]: [18.72578916], [24.]
# predict_Y[i], Y[i]: [10.99872248], [8.]
# predict_Y[i], Y[i]: [19.62735977], [23.]
# predict_Y[i], Y[i]: [45.41617973], [49.]
# predict_Y[i], Y[i]: [9.8868558], [20.]
# predict_Y[i], Y[i]: [6.57754122], [6.]
# predict_Y[i], Y[i]: [11.38781034], [9.]
# predict_Y[i], Y[i]: [8.51001716], [7.]
# predict_Y[i], Y[i]: [9.52255165], [12.]
# predict_Y[i], Y[i]: [20.13759278], [15.]
# predict_Y[i], Y[i]: [11.27174067], [11.]
# predict_Y[i], Y[i]: [19.17761166], [16.]
# predict_Y[i], Y[i]: [3.2618924], [4.]
# predict_Y[i], Y[i]: [12.26046697], [10.]
# predict_Y[i], Y[i]: [12.23411904], [22.]
# predict_Y[i], Y[i]: [3.6804225], [11.]
# predict_Y[i], Y[i]: [7.05806917], [9.]
# predict_Y[i], Y[i]: [32.54542083], [20.]
# predict_Y[i], Y[i]: [39.13776958], [42.]
# predict_Y[i], Y[i]: [6.94703017], [9.]
# predict_Y[i], Y[i]: [9.15348462], [11.]
# predict_Y[i], Y[i]: [19.60195025], [21.]
# predict_Y[i], Y[i]: [16.85756333], [22.]
# predict_Y[i], Y[i]: [15.0366953], [14.]
# predict_Y[i], Y[i]: [14.35368825], [8.]
# predict_Y[i], Y[i]: [13.48831966], [14.]
# predict_Y[i], Y[i]: [5.7631283], [5.]
# predict_Y[i], Y[i]: [9.16623748], [6.]
# predict_Y[i], Y[i]: [8.43225631], [5.]
# predict_Y[i], Y[i]: [29.57927694], [26.]
# predict_Y[i], Y[i]: [10.76388125], [9.]
# predict_Y[i], Y[i]: [9.62586194], [9.]
# predict_Y[i], Y[i]: [5.3788048], [6.]
# predict_Y[i], Y[i]: [14.7687119], [10.]
# predict_Y[i], Y[i]: [47.8117555], [46.]
# predict_Y[i], Y[i]: [19.87178944], [15.]
# predict_Y[i], Y[i]: [8.58529148], [11.]
# predict_Y[i], Y[i]: [13.2020825], [12.]
# predict_Y[i], Y[i]: [11.9572096], [13.]
# predict_Y[i], Y[i]: [1.76490069], [7.]
# predict_Y[i], Y[i]: [22.34006157], [22.]
# predict_Y[i], Y[i]: [7.79975188], [8.]
# predict_Y[i], Y[i]: [10.56143447], [10.]
# predict_Y[i], Y[i]: [12.65112357], [10.]
# predict_Y[i], Y[i]: [20.99016258], [21.]
# predict_Y[i], Y[i]: [8.94662453], [12.]
# predict_Y[i], Y[i]: [13.04092278], [12.]
# predict_Y[i], Y[i]: [20.5234808], [26.]
# predict_Y[i], Y[i]: [6.36568675], [11.]
# predict_Y[i], Y[i]: [20.42410799], [17.]
# predict_Y[i], Y[i]: [7.03255376], [8.]
# predict_Y[i], Y[i]: [38.3619531], [29.]
# predict_Y[i], Y[i]: [1.92719476], [0.]
# predict_Y[i], Y[i]: [9.03076662], [7.]
# predict_Y[i], Y[i]: [8.52775976], [10.]
# predict_Y[i], Y[i]: [7.78647263], [5.]
# predict_Y[i], Y[i]: [9.29591189], [9.]
# predict_Y[i], Y[i]: [14.44247434], [23.]
# predict_Y[i], Y[i]: [7.78206621], [12.]
# predict_Y[i], Y[i]: [6.5068586], [6.]
# predict_Y[i], Y[i]: [18.54746058], [21.]
# predict_Y[i], Y[i]: [11.7758975], [10.]
# predict_Y[i], Y[i]: [4.33243663], [11.]
# predict_Y[i], Y[i]: [22.47467412], [24.]
# predict_Y[i], Y[i]: [8.02313752], [8.]
# predict_Y[i], Y[i]: [19.59233951], [18.]
# predict_Y[i], Y[i]: [13.65173562], [13.]
# predict_Y[i], Y[i]: [14.10158197], [10.]
# predict_Y[i], Y[i]: [19.29066938], [21.]
# predict_Y[i], Y[i]: [6.92398272], [6.]
# predict_Y[i], Y[i]: [9.68324592], [8.]
# predict_Y[i], Y[i]: [6.5409916], [4.]
# predict_Y[i], Y[i]: [12.42090963], [9.]
# predict_Y[i], Y[i]: [11.74818839], [11.]
# predict_Y[i], Y[i]: [5.80972498], [8.]
# predict_Y[i], Y[i]: [11.43241729], [11.]
# predict_Y[i], Y[i]: [18.5529225], [17.]
# predict_Y[i], Y[i]: [8.78754404], [10.]
# predict_Y[i], Y[i]: [15.9302821], [12.]
# predict_Y[i], Y[i]: [9.13930538], [13.]
# predict_Y[i], Y[i]: [10.15193779], [6.]
# predict_Y[i], Y[i]: [35.44596411], [43.]
# predict_Y[i], Y[i]: [12.12534486], [11.]
# predict_Y[i], Y[i]: [16.09114729], [14.]
# predict_Y[i], Y[i]: [4.96417607], [6.]
# predict_Y[i], Y[i]: [18.30020687], [19.]
# predict_Y[i], Y[i]: [6.40247188], [5.]
# predict_Y[i], Y[i]: [25.50000094], [32.]
# predict_Y[i], Y[i]: [15.81156479], [14.]
# predict_Y[i], Y[i]: [8.03597283], [5.]
# predict_Y[i], Y[i]: [7.24449678], [7.]
# predict_Y[i], Y[i]: [18.44113695], [18.]
# predict_Y[i], Y[i]: [3.74840269], [5.]
# predict_Y[i], Y[i]: [5.82518683], [10.]
# predict_Y[i], Y[i]: [29.1719381], [32.]
# predict_Y[i], Y[i]: [15.07780312], [17.]
# predict_Y[i], Y[i]: [5.4578279], [8.]
# predict_Y[i], Y[i]: [8.2351487], [9.]
# predict_Y[i], Y[i]: [6.51080964], [8.]
# predict_Y[i], Y[i]: [13.8971602], [19.]
# predict_Y[i], Y[i]: [13.59993222], [11.]
# predict_Y[i], Y[i]: [8.86218469], [7.]
# predict_Y[i], Y[i]: [10.4013642], [10.]
# predict_Y[i], Y[i]: [64.79113217], [56.]
# predict_Y[i], Y[i]: [9.59116251], [9.]
# predict_Y[i], Y[i]: [12.62385619], [17.]
# predict_Y[i], Y[i]: [8.66135812], [8.]
# predict_Y[i], Y[i]: [11.07246587], [9.]
# predict_Y[i], Y[i]: [18.72430589], [20.]
# predict_Y[i], Y[i]: [8.7753869], [8.]
# predict_Y[i], Y[i]: [5.63245758], [4.]
# predict_Y[i], Y[i]: [26.54228791], [21.]
# predict_Y[i], Y[i]: [10.72416126], [10.]
# predict_Y[i], Y[i]: [11.41134433], [10.]
# predict_Y[i], Y[i]: [7.98573235], [9.]
# predict_Y[i], Y[i]: [14.9168012], [14.]
# predict_Y[i], Y[i]: [12.50246256], [11.]
# predict_Y[i], Y[i]: [14.93877461], [17.]
# predict_Y[i], Y[i]: [20.58504814], [17.]
# predict_Y[i], Y[i]: [19.25612206], [23.]
# predict_Y[i], Y[i]: [24.17144626], [28.]
# predict_Y[i], Y[i]: [6.10391442], [8.]
# predict_Y[i], Y[i]: [10.48814385], [10.]
# predict_Y[i], Y[i]: [8.21158871], [8.]
# predict_Y[i], Y[i]: [4.32306755], [6.]
# predict_Y[i], Y[i]: [20.88574787], [25.]
# predict_Y[i], Y[i]: [6.26956506], [8.]
# predict_Y[i], Y[i]: [21.98400838], [19.]
# predict_Y[i], Y[i]: [10.48768851], [8.]
# predict_Y[i], Y[i]: [5.18442658], [8.]
# predict_Y[i], Y[i]: [7.21827347], [6.]
# predict_Y[i], Y[i]: [24.47026219], [32.]
# predict_Y[i], Y[i]: [14.51982673], [16.]
# predict_Y[i], Y[i]: [10.81509328], [21.]
# predict_Y[i], Y[i]: [14.42752266], [14.]
# predict_Y[i], Y[i]: [4.3169837], [12.]
# predict_Y[i], Y[i]: [12.00630325], [10.]
# predict_Y[i], Y[i]: [12.38417327], [13.]
# predict_Y[i], Y[i]: [9.86382634], [9.]
# predict_Y[i], Y[i]: [37.60064284], [33.]
# predict_Y[i], Y[i]: [11.80069633], [10.]
# predict_Y[i], Y[i]: [12.04112539], [18.]
# predict_Y[i], Y[i]: [12.83736222], [13.]
# predict_Y[i], Y[i]: [10.79102295], [10.]
# predict_Y[i], Y[i]: [23.16887192], [34.]
# predict_Y[i], Y[i]: [23.1917147], [22.]
# predict_Y[i], Y[i]: [8.15543093], [9.]
# predict_Y[i], Y[i]: [13.8993361], [10.]
# predict_Y[i], Y[i]: [2.32094019], [0.]
# predict_Y[i], Y[i]: [10.20274456], [10.]
# predict_Y[i], Y[i]: [9.21260092], [8.]
# predict_Y[i], Y[i]: [39.52979411], [38.]
# predict_Y[i], Y[i]: [10.75904575], [9.]
# predict_Y[i], Y[i]: [17.01901037], [19.]
# predict_Y[i], Y[i]: [8.88539855], [7.]
# predict_Y[i], Y[i]: [6.60101681], [5.]
# predict_Y[i], Y[i]: [4.05241019], [12.]
# predict_Y[i], Y[i]: [21.11324257], [25.]
# predict_Y[i], Y[i]: [9.13060299], [14.]
# predict_Y[i], Y[i]: [24.40636063], [27.]
# predict_Y[i], Y[i]: [13.50797118], [16.]
# predict_Y[i], Y[i]: [11.3479207], [15.]
# predict_Y[i], Y[i]: [8.81910173], [6.]
# predict_Y[i], Y[i]: [12.77000943], [11.]
# predict_Y[i], Y[i]: [5.90299081], [8.]
# predict_Y[i], Y[i]: [6.12450155], [6.]
# predict_Y[i], Y[i]: [4.53237894], [2.]
# predict_Y[i], Y[i]: [45.89477308], [42.]
# predict_Y[i], Y[i]: [6.34743357], [9.]
# predict_Y[i], Y[i]: [10.90366171], [14.]
# predict_Y[i], Y[i]: [11.54887284], [10.]
# predict_Y[i], Y[i]: [13.13032537], [9.]
# predict_Y[i], Y[i]: [7.1558362], [4.]
# predict_Y[i], Y[i]: [8.11668293], [6.]
# predict_Y[i], Y[i]: [9.33183815], [9.]
# predict_Y[i], Y[i]: [8.42942103], [5.]
# predict_Y[i], Y[i]: [27.76227086], [24.]
# predict_Y[i], Y[i]: [14.40271134], [11.]
# predict_Y[i], Y[i]: [14.8976893], [12.]
# predict_Y[i], Y[i]: [18.96863062], [23.]
# predict_Y[i], Y[i]: [24.65225369], [19.]
# predict_Y[i], Y[i]: [15.25690006], [17.]
# predict_Y[i], Y[i]: [40.54342639], [34.]
# predict_Y[i], Y[i]: [12.30088093], [13.]
# predict_Y[i], Y[i]: [11.14454676], [7.]
# predict_Y[i], Y[i]: [5.70262007], [7.]
# predict_Y[i], Y[i]: [14.10239931], [17.]
# predict_Y[i], Y[i]: [40.25486637], [47.]
# predict_Y[i], Y[i]: [18.42272294], [20.]
# predict_Y[i], Y[i]: [7.23031171], [8.]
# predict_Y[i], Y[i]: [16.74973571], [25.]
# predict_Y[i], Y[i]: [7.15342328], [13.]
# predict_Y[i], Y[i]: [9.6670875], [15.]
# predict_Y[i], Y[i]: [11.58169267], [8.]
# predict_Y[i], Y[i]: [17.06931059], [7.]
# predict_Y[i], Y[i]: [14.46078134], [19.]
# predict_Y[i], Y[i]: [7.07516897], [5.]
# predict_Y[i], Y[i]: [19.71003548], [22.]
# predict_Y[i], Y[i]: [8.6177886], [8.]
# predict_Y[i], Y[i]: [8.64104515], [10.]
# predict_Y[i], Y[i]: [7.97238265], [6.]
# predict_Y[i], Y[i]: [13.61464405], [13.]
# predict_Y[i], Y[i]: [22.977543], [22.]
# predict_Y[i], Y[i]: [10.98380977], [14.]
# predict_Y[i], Y[i]: [3.41942449], [1.]
# predict_Y[i], Y[i]: [7.93538014], [5.]
# predict_Y[i], Y[i]: [13.74480142], [18.]
# predict_Y[i], Y[i]: [7.9657471], [9.]
# predict_Y[i], Y[i]: [9.5492227], [10.]
# predict_Y[i], Y[i]: [4.98139985], [3.]
# predict_Y[i], Y[i]: [9.69309722], [12.]
# predict_Y[i], Y[i]: [14.70167404], [15.]
# predict_Y[i], Y[i]: [8.01204254], [6.]
# predict_Y[i], Y[i]: [23.85422285], [22.]
# predict_Y[i], Y[i]: [14.11072769], [18.]
# predict_Y[i], Y[i]: [8.39556234], [11.]
# predict_Y[i], Y[i]: [9.66485272], [10.]
# predict_Y[i], Y[i]: [32.82472132], [40.]
# predict_Y[i], Y[i]: [8.8226201], [11.]
# predict_Y[i], Y[i]: [13.58800131], [11.]
# predict_Y[i], Y[i]: [20.12755362], [28.]
# predict_Y[i], Y[i]: [9.44884055], [9.]
# predict_Y[i], Y[i]: [17.61380498], [14.]
# predict_Y[i], Y[i]: [6.53230608], [2.]
# predict_Y[i], Y[i]: [14.24990298], [14.]
# predict_Y[i], Y[i]: [7.23159223], [8.]
# predict_Y[i], Y[i]: [5.31650288], [4.]
# predict_Y[i], Y[i]: [3.39636727], [2.]
# predict_Y[i], Y[i]: [18.46128545], [20.]
# predict_Y[i], Y[i]: [9.88190038], [10.]
# predict_Y[i], Y[i]: [5.48822495], [8.]
# predict_Y[i], Y[i]: [14.09336811], [11.]
# predict_Y[i], Y[i]: [7.59745404], [6.]
# predict_Y[i], Y[i]: [29.18103039], [26.]
# predict_Y[i], Y[i]: [14.02141316], [10.]
# predict_Y[i], Y[i]: [10.02997478], [13.]
# predict_Y[i], Y[i]: [13.57992221], [19.]
# predict_Y[i], Y[i]: [26.3362301], [30.]
# predict_Y[i], Y[i]: [21.85795588], [17.]
# predict_Y[i], Y[i]: [9.19203306], [4.]
# predict_Y[i], Y[i]: [29.29580587], [28.]
# predict_Y[i], Y[i]: [11.85641845], [20.]
# predict_Y[i], Y[i]: [10.13114962], [9.]
# predict_rmse: 4.420413951294509
# ================= testing =================
# write complete!
